# %% [markdown]
# ### **This Notebook Performs a Parameters Search on Every Possible Cleaning and Model Parameter.**

# %% [markdown]
# Lets test different spectral cleaning parameters by building a model pipeline.

# %% [markdown]
# Import Libraries

# %%
import pandas as pd
import numpy as np
from scipy.signal import savgol_filter
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.svm import SVC
from sklearn.model_selection import cross_validate, GroupKFold
from Spectra_Preparation_Functions import *
import optuna

# %% [markdown]
# Read the spectral data

# %%
#df = pd.read_csv("../../data/exosomes.raw_spectrum_1.csv")
# df = pd.read_csv("../../data/raw_df_outliers_removed.csv")
df = pd.read_csv("../../data/exosomes.raw_spectrum_400-1800.csv")

# %%
df
# Out:
#               SpecID   Seq  WaveNumber  Absorbance     SurID         Status
# 0        201210-1-00   293   400.22778   1765.6628  201210-1         Normal
# 1        201210-1-00   294   400.91116   1774.7809  201210-1         Normal
# 2        201210-1-00   295   401.59454   1769.0302  201210-1         Normal
# 3        201210-1-00   296   402.27789   1756.4220  201210-1         Normal
# 4        201210-1-00   297   402.96127   1758.8690  201210-1         Normal
# ...              ...   ...         ...         ...       ...            ...
# 6239200  210526-3-09  2337  1797.03870   1617.3926  210526-3  Hyperglycemia
# 6239201  210526-3-09  2338  1797.72200   1633.0911  210526-3  Hyperglycemia
# 6239202  210526-3-09  2339  1798.40550   1633.3076  210526-3  Hyperglycemia
# 6239203  210526-3-09  2340  1799.08890   1641.8665  210526-3  Hyperglycemia
# 6239204  210526-3-09  2341  1799.77220   1618.2405  210526-3  Hyperglycemia
#
# [6239205 rows x 6 columns]

# %%
wavelength_df = prepare_wavelength_df(df, 'Absorbance')
wavelength_df.head()
# Out:
#              400.22778  400.91116  401.59454  402.27789  402.96127  403.64465  \
# SpecID
# 201210-1-00  1765.6628  1774.7809  1769.0302  1756.4220  1758.8690  1763.2300
# 201210-1-01  1966.9930  1962.4237  1954.5616  1954.3228  1963.0917  1975.0807
# 201210-1-02  2182.6694  2149.6565  2146.0227  2159.3459  2167.2910  2160.9861
# 201210-1-03  2445.0837  2430.4973  2422.7927  2434.3433  2454.9700  2462.8245
# 201210-1-04  2250.4536  2248.6235  2245.0984  2242.7173  2235.2803  2228.9585
#
#              404.32803  405.01138  405.69476  406.37814  ...  1794.9886  \
# SpecID                                                   ...
# 201210-1-00  1745.2285  1773.3534  1774.7166  1753.3281  ...  1210.4993
# 201210-1-01  1979.3162  1963.4561  1968.4587  1964.0000  ...  1382.6973
# 201210-1-02  2145.6575  2134.2004  2142.8303  2138.6309  ...  1976.2070
# 201210-1-03  2454.7007  2467.7329  2449.5161  2421.3474  ...  1992.3817
# 201210-1-04  2236.0095  2229.6091  2225.9231  2211.0359  ...  2009.0385
#
#               1795.672  1796.3553  1797.0387   1797.722  1798.4055  1799.0889  \
# SpecID
# 201210-1-00  1213.9619  1225.2153  1210.0010  1210.6858  1194.4679  1195.1451
# 201210-1-01  1363.7004  1360.6210  1354.0477  1353.0381  1353.9978  1361.2426
# 201210-1-02  1989.0183  1996.2838  1979.3507  1976.2002  1994.9839  1974.2030
# 201210-1-03  2022.6331  2001.8311  2010.0946  2006.4933  2017.2891  2038.1699
# 201210-1-04  1953.3303  1963.5698  1964.5299  1969.5634  1986.6266  1970.1484
#
#              1799.7722     SurID  Status
# SpecID
# 201210-1-00  1189.8683  201210-1  Normal
# 201210-1-01  1370.2874  201210-1  Normal
# 201210-1-02  1971.1880  201210-1  Normal
# 201210-1-03  2000.6475  201210-1  Normal
# 201210-1-04  2007.0848  201210-1  Normal
#
# [5 rows x 2051 columns]

# %% [markdown]
# >#### **Use Optuna to Find the Best Cleaning Parameter**

# %%
df
# Out:
#               SpecID   Seq  WaveNumber  Absorbance     SurID         Status
# 0        201210-1-00   293   400.22778   1765.6628  201210-1         Normal
# 1        201210-1-00   294   400.91116   1774.7809  201210-1         Normal
# 2        201210-1-00   295   401.59454   1769.0302  201210-1         Normal
# 3        201210-1-00   296   402.27789   1756.4220  201210-1         Normal
# 4        201210-1-00   297   402.96127   1758.8690  201210-1         Normal
# ...              ...   ...         ...         ...       ...            ...
# 6239200  210526-3-09  2337  1797.03870   1617.3926  210526-3  Hyperglycemia
# 6239201  210526-3-09  2338  1797.72200   1633.0911  210526-3  Hyperglycemia
# 6239202  210526-3-09  2339  1798.40550   1633.3076  210526-3  Hyperglycemia
# 6239203  210526-3-09  2340  1799.08890   1641.8665  210526-3  Hyperglycemia
# 6239204  210526-3-09  2341  1799.77220   1618.2405  210526-3  Hyperglycemia
#
# [6239205 rows x 6 columns]

# %%
def objective(trial):

    # Decide which cleaning steps to implement
    despike = trial.suggest_categorical('despike', [True, False])
    baseline_correct = trial.suggest_categorical('baseline_correct', [True, False])
    smoothing = trial.suggest_categorical('smoothing', [True, False])
    scaling = trial.suggest_categorical('scaling', [True, False])

    df_copy = df.copy()

    # Apply preprocessing based on suggested parameters
    if despike:
        despike_ma = trial.suggest_int('despike_ma', 5, 200)
        despike_threshold = trial.suggest_float('despike_threshold', 3, 10, step=0.1)
        df_copy['Absorbance'] = df_copy.groupby('SpecID')['Absorbance'].transform(lambda x: despike_group(x, ma=despike_ma, threshold = despike_threshold))

    if baseline_correct:
        lam = trial.suggest_categorical('lam', [10**2, 10**3, 10**4, 10**5, 10**6, 10**7, 10**8, 10**9, 10**10, 10**11])
        p = trial.suggest_float('p', 0.001, 0.1, step=0.001)
        df_copy['Baseline'] = df_copy.groupby('SpecID')['Absorbance'].transform(lambda x: asls_baseline_correction(x, lam=lam, p=p))
        df_copy['Absorbance'] = df_copy['Absorbance'] - df_copy['Baseline']

    if smoothing:
        window_size = trial.suggest_int('window_size', 6, 251)
        poly_order = trial.suggest_int('poly_order', 1, 5)
        df_copy['Absorbance'] = df_copy.groupby('SpecID')['Absorbance'].transform(lambda x: savgol_filter(x, window_size, poly_order, deriv=0))

    if scaling:
        scaling_type = trial.suggest_categorical('scaling_type', ['normal', 'vector', 'snv'])
        if scaling_type == 'normal':
            df_copy['Absorbance'] = df_copy.groupby('SpecID')['Absorbance'].transform(lambda x: normalise(x))
        elif scaling_type == 'vector':
            df_copy['Absorbance'] = df_copy.groupby('SpecID')['Absorbance'].transform(lambda x: vector_normalise(x))
        else:
            df_copy['Absorbance'] = df_copy.groupby('SpecID')['Absorbance'].transform(lambda x: snv_normalise(x))

    # Prepare data for ML
    wavelength_df = prepare_wavelength_df(df_copy, 'Absorbance')
    X = wavelength_df.drop(['Status', 'SurID'], axis=1)
    y = wavelength_df['Status']
    groups = wavelength_df['SurID']

    # Suggest classifier type
    classifier_name = trial.suggest_categorical("classifier", ["ExtraTrees", "RandomForest", "SVC"])

    if classifier_name == "ExtraTrees":
        criterion = trial.suggest_categorical("et_criterion", ["gini", "entropy"])
        n_estimators = trial.suggest_int("et_n_estimators", 10, 100)
        max_depth_option = trial.suggest_categorical("et_max_depth_option", [None, "Specify"])
        max_depth = trial.suggest_int("et_max_depth", 2, 32, log=True) if max_depth_option == "Specify" else None
        classifier = ExtraTreesClassifier(random_state=1234, criterion=criterion, n_estimators=n_estimators, max_depth=max_depth)

    elif classifier_name == "RandomForest":
        criterion = trial.suggest_categorical("rf_criterion", ["gini", "entropy"])
        n_estimators = trial.suggest_int("rf_n_estimators", 10, 100)
        max_depth_option = trial.suggest_categorical("rf_max_depth_option", [None, "Specify"])
        max_depth = trial.suggest_int("rf_max_depth", 2, 32, log=True) if max_depth_option == "Specify" else None
        classifier = RandomForestClassifier(random_state=1234, criterion=criterion, n_estimators=n_estimators, max_depth=max_depth)
        
    else:
        classifier = SVC(
            C=trial.suggest_float("svc_c", 1e-10, 1e10, log=True),
            kernel=trial.suggest_categorical("svc_kernel", ["linear", "poly", "rbf", "sigmoid"]),
            gamma=trial.suggest_categorical("svc_gamma", ["scale", "auto"]),
            random_state=1234,
        )

    cv = GroupKFold(n_splits=10)

    # Perform cross-validation
    scores = cross_validate(classifier, X, y, groups=groups, cv=cv, scoring='f1_macro')

    # Return the average f1_score across all folds
    return np.mean(scores['test_score'])


sampler = optuna.samplers.TPESampler(seed=1234)  # Make the sampler behave in a deterministic way.
study = optuna.create_study(direction='maximize', sampler=sampler)

#study = optuna.create_study(direction="maximize")
# study.optimize(objective, n_trials=100, n_jobs=-1)
study.optimize(objective, n_trials=500, n_jobs=-1)

print(study.best_trial)
# Out:
# [I 2024-04-17 23:09:12,158] A new study created in memory with name: no-name-c31c444c-5516-4b69-84e6-5e87b3ff5270
# [I 2024-04-17 23:10:53,657] Trial 1 finished with value: 0.5266991580814315 and parameters: {'despike': False, 'baseline_correct': False, 'smoothing': False, 'scaling': True, 'scaling_type': 'snv', 'classifier': 'RandomForest', 'rf_criterion': 'entropy', 'rf_n_estimators': 11, 'rf_max_depth_option': None}. Best is trial 1 with value: 0.5266991580814315.
# [I 2024-04-17 23:11:05,421] Trial 9 finished with value: 0.50593150041534 and parameters: {'despike': False, 'baseline_correct': False, 'smoothing': False, 'scaling': False, 'classifier': 'RandomForest', 'rf_criterion': 'entropy', 'rf_n_estimators': 61, 'rf_max_depth_option': None}. Best is trial 1 with value: 0.5266991580814315.
# [I 2024-04-17 23:11:16,650] Trial 5 finished with value: 0.4703469944526459 and parameters: {'despike': True, 'baseline_correct': False, 'smoothing': False, 'scaling': False, 'despike_ma': 55, 'despike_threshold': 4.0, 'classifier': 'ExtraTrees', 'et_criterion': 'entropy', 'et_n_estimators': 52, 'et_max_depth_option': 'Specify', 'et_max_depth': 10}. Best is trial 1 with value: 0.5266991580814315.
# [I 2024-04-17 23:12:01,154] Trial 2 finished with value: 0.46111137452451345 and parameters: {'despike': False, 'baseline_correct': False, 'smoothing': True, 'scaling': True, 'window_size': 10, 'poly_order': 1, 'scaling_type': 'normal', 'classifier': 'SVC', 'svc_c': 0.02505654781196157, 'svc_kernel': 'linear', 'svc_gamma': 'scale'}. Best is trial 1 with value: 0.5266991580814315.
# [I 2024-04-17 23:13:09,171] Trial 11 finished with value: 0.5162690487603387 and parameters: {'despike': False, 'baseline_correct': False, 'smoothing': False, 'scaling': True, 'scaling_type': 'normal', 'classifier': 'SVC', 'svc_c': 3550.1692783102103, 'svc_kernel': 'linear', 'svc_gamma': 'scale'}. Best is trial 1 with value: 0.5266991580814315.
# [I 2024-04-17 23:16:09,811] Trial 6 finished with value: 0.1221034513995833 and parameters: {'despike': True, 'baseline_correct': False, 'smoothing': True, 'scaling': False, 'despike_ma': 35, 'despike_threshold': 8.600000000000001, 'window_size': 9, 'poly_order': 4, 'classifier': 'SVC', 'svc_c': 19341006.657064784, 'svc_kernel': 'rbf', 'svc_gamma': 'auto'}. Best is trial 1 with value: 0.5266991580814315.
# [I 2024-04-17 23:17:33,487] Trial 12 finished with value: 0.4042269867378062 and parameters: {'despike': True, 'baseline_correct': True, 'smoothing': False, 'scaling': False, 'despike_ma': 108, 'despike_threshold': 9.7, 'lam': 100, 'p': 0.095, 'classifier': 'ExtraTrees', 'et_criterion': 'entropy', 'et_n_estimators': 12, 'et_max_depth_option': 'Specify', 'et_max_depth': 12}. Best is trial 1 with value: 0.5266991580814315.
# [I 2024-04-17 23:17:55,265] Trial 0 finished with value: 0.5537155927709746 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 1000000, 'p': 0.053000000000000005, 'window_size': 148, 'poly_order': 4, 'classifier': 'ExtraTrees', 'et_criterion': 'entropy', 'et_n_estimators': 38, 'et_max_depth_option': None}. Best is trial 0 with value: 0.5537155927709746.
# [I 2024-04-17 23:18:14,214] Trial 10 finished with value: 0.5918066754371065 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 1000000000, 'p': 0.091, 'window_size': 50, 'poly_order': 2, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 85, 'rf_max_depth_option': None}. Best is trial 10 with value: 0.5918066754371065.
# [I 2024-04-17 23:18:26,092] Trial 15 finished with value: 0.4635912963232586 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': False, 'scaling': False, 'lam': 100000, 'p': 0.013000000000000001, 'classifier': 'ExtraTrees', 'et_criterion': 'entropy', 'et_n_estimators': 59, 'et_max_depth_option': 'Specify', 'et_max_depth': 10}. Best is trial 10 with value: 0.5918066754371065.
# [I 2024-04-17 23:18:35,792] Trial 3 finished with value: 0.44917478035438324 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': True, 'lam': 10000, 'p': 0.089, 'window_size': 137, 'poly_order': 2, 'scaling_type': 'vector', 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 66, 'rf_max_depth_option': None}. Best is trial 10 with value: 0.5918066754371065.
# [I 2024-04-17 23:18:40,188] Trial 17 finished with value: 0.5123137119232403 and parameters: {'despike': True, 'baseline_correct': False, 'smoothing': False, 'scaling': True, 'despike_ma': 95, 'despike_threshold': 7.3, 'scaling_type': 'vector', 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 35, 'rf_max_depth_option': None}. Best is trial 10 with value: 0.5918066754371065.
# [I 2024-04-17 23:18:53,719] Trial 4 finished with value: 0.5175079093907226 and parameters: {'despike': True, 'baseline_correct': True, 'smoothing': False, 'scaling': True, 'despike_ma': 67, 'despike_threshold': 7.7, 'lam': 10000000, 'p': 0.006, 'scaling_type': 'snv', 'classifier': 'ExtraTrees', 'et_criterion': 'gini', 'et_n_estimators': 91, 'et_max_depth_option': None}. Best is trial 10 with value: 0.5918066754371065.
# [I 2024-04-17 23:18:59,300] Trial 13 finished with value: 0.46164698953657124 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': False, 'scaling': True, 'lam': 100000, 'p': 0.065, 'scaling_type': 'vector', 'classifier': 'RandomForest', 'rf_criterion': 'entropy', 'rf_n_estimators': 45, 'rf_max_depth_option': None}. Best is trial 10 with value: 0.5918066754371065.
# [I 2024-04-17 23:19:00,752] Trial 14 finished with value: 0.46469900811567 and parameters: {'despike': True, 'baseline_correct': True, 'smoothing': True, 'scaling': True, 'despike_ma': 192, 'despike_threshold': 9.2, 'lam': 1000000, 'p': 0.07300000000000001, 'window_size': 182, 'poly_order': 1, 'scaling_type': 'normal', 'classifier': 'ExtraTrees', 'et_criterion': 'gini', 'et_n_estimators': 59, 'et_max_depth_option': 'Specify', 'et_max_depth': 18}. Best is trial 10 with value: 0.5918066754371065.
# [I 2024-04-17 23:19:07,438] Trial 7 finished with value: 0.4555388916856476 and parameters: {'despike': True, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'despike_ma': 57, 'despike_threshold': 6.1, 'lam': 100000, 'p': 0.035, 'window_size': 57, 'poly_order': 3, 'classifier': 'SVC', 'svc_c': 3.294732564666532, 'svc_kernel': 'rbf', 'svc_gamma': 'scale'}. Best is trial 10 with value: 0.5918066754371065.
# [I 2024-04-17 23:21:44,188] Trial 8 finished with value: 0.1221034513995833 and parameters: {'despike': True, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'despike_ma': 36, 'despike_threshold': 3.5, 'lam': 10000000000, 'p': 0.022000000000000002, 'window_size': 246, 'poly_order': 4, 'classifier': 'SVC', 'svc_c': 153441.04081101096, 'svc_kernel': 'rbf', 'svc_gamma': 'auto'}. Best is trial 10 with value: 0.5918066754371065.
# [I 2024-04-17 23:22:05,448] Trial 16 finished with value: 0.49923253457772443 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': False, 'scaling': False, 'lam': 10000, 'p': 0.044000000000000004, 'classifier': 'RandomForest', 'rf_criterion': 'entropy', 'rf_n_estimators': 99, 'rf_max_depth_option': 'Specify', 'rf_max_depth': 17}. Best is trial 10 with value: 0.5918066754371065.
# [I 2024-04-17 23:24:10,116] Trial 23 finished with value: 0.5464739213364933 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 1000000000, 'p': 0.049, 'window_size': 235, 'poly_order': 5, 'classifier': 'ExtraTrees', 'et_criterion': 'gini', 'et_n_estimators': 23, 'et_max_depth_option': None}. Best is trial 10 with value: 0.5918066754371065.
# [I 2024-04-17 23:24:14,324] Trial 26 finished with value: 0.5699739143137853 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 1000000000, 'p': 0.044000000000000004, 'window_size': 99, 'poly_order': 5, 'classifier': 'ExtraTrees', 'et_criterion': 'entropy', 'et_n_estimators': 19, 'et_max_depth_option': None}. Best is trial 10 with value: 0.5918066754371065.
# [I 2024-04-17 23:24:15,106] Trial 25 finished with value: 0.5483648311413767 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 1000000, 'p': 0.048, 'window_size': 246, 'poly_order': 5, 'classifier': 'ExtraTrees', 'et_criterion': 'gini', 'et_n_estimators': 25, 'et_max_depth_option': None}. Best is trial 10 with value: 0.5918066754371065.
# [I 2024-04-17 23:24:27,701] Trial 18 finished with value: 0.4169681827940117 and parameters: {'despike': True, 'baseline_correct': True, 'smoothing': True, 'scaling': True, 'despike_ma': 88, 'despike_threshold': 9.0, 'lam': 1000, 'p': 0.098, 'window_size': 177, 'poly_order': 2, 'scaling_type': 'normal', 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 79, 'rf_max_depth_option': 'Specify', 'rf_max_depth': 4}. Best is trial 10 with value: 0.5918066754371065.
# [I 2024-04-17 23:24:27,991] Trial 28 finished with value: 0.5734965183509797 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 1000000000, 'p': 0.049, 'window_size': 101, 'poly_order': 5, 'classifier': 'ExtraTrees', 'et_criterion': 'entropy', 'et_n_estimators': 17, 'et_max_depth_option': None}. Best is trial 10 with value: 0.5918066754371065.
# [I 2024-04-17 23:24:30,355] Trial 29 finished with value: 0.5759838819711305 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 1000000000, 'p': 0.065, 'window_size': 97, 'poly_order': 5, 'classifier': 'ExtraTrees', 'et_criterion': 'entropy', 'et_n_estimators': 20, 'et_max_depth_option': None}. Best is trial 10 with value: 0.5918066754371065.
# [I 2024-04-17 23:24:35,368] Trial 20 finished with value: 0.5276660235154929 and parameters: {'despike': True, 'baseline_correct': True, 'smoothing': False, 'scaling': False, 'despike_ma': 27, 'despike_threshold': 4.0, 'lam': 100000000000, 'p': 0.053000000000000005, 'classifier': 'RandomForest', 'rf_criterion': 'entropy', 'rf_n_estimators': 85, 'rf_max_depth_option': 'Specify', 'rf_max_depth': 5}. Best is trial 10 with value: 0.5918066754371065.
# [I 2024-04-17 23:25:11,850] Trial 19 finished with value: 0.5387858889303536 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 100000, 'p': 0.001, 'window_size': 216, 'poly_order': 4, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 67, 'rf_max_depth_option': 'Specify', 'rf_max_depth': 28}. Best is trial 10 with value: 0.5918066754371065.
# [I 2024-04-17 23:25:20,219] Trial 24 finished with value: 0.5805816721087191 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 1000000000, 'p': 0.061, 'window_size': 234, 'poly_order': 5, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 98, 'rf_max_depth_option': 'Specify', 'rf_max_depth': 9}. Best is trial 10 with value: 0.5918066754371065.
# [I 2024-04-17 23:25:31,665] Trial 22 finished with value: 0.5549806790022083 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 1000000, 'p': 0.05, 'window_size': 222, 'poly_order': 5, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 99, 'rf_max_depth_option': 'Specify', 'rf_max_depth': 15}. Best is trial 10 with value: 0.5918066754371065.
# [I 2024-04-17 23:25:35,111] Trial 21 finished with value: 0.4981909650182077 and parameters: {'despike': True, 'baseline_correct': True, 'smoothing': True, 'scaling': True, 'despike_ma': 198, 'despike_threshold': 3.2, 'lam': 1000000000, 'p': 0.1, 'window_size': 221, 'poly_order': 1, 'scaling_type': 'vector', 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 93, 'rf_max_depth_option': 'Specify', 'rf_max_depth': 7}. Best is trial 10 with value: 0.5918066754371065.
# [I 2024-04-17 23:25:37,042] Trial 27 finished with value: 0.5905474186333979 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 1000000000, 'p': 0.045, 'window_size': 107, 'poly_order': 5, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 99, 'rf_max_depth_option': 'Specify', 'rf_max_depth': 13}. Best is trial 10 with value: 0.5918066754371065.
# [I 2024-04-17 23:25:41,109] Trial 32 finished with value: 0.5902493965746344 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 1000000000, 'p': 0.07200000000000001, 'window_size': 91, 'poly_order': 4, 'classifier': 'ExtraTrees', 'et_criterion': 'entropy', 'et_n_estimators': 42, 'et_max_depth_option': None}. Best is trial 10 with value: 0.5918066754371065.
# [I 2024-04-17 23:25:49,697] Trial 34 finished with value: 0.5664874364830721 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 1000000000, 'p': 0.069, 'window_size': 75, 'poly_order': 5, 'classifier': 'ExtraTrees', 'et_criterion': 'entropy', 'et_n_estimators': 16, 'et_max_depth_option': None}. Best is trial 10 with value: 0.5918066754371065.
# [I 2024-04-17 23:25:52,921] Trial 30 finished with value: 0.399107458486773 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 1000000000, 'p': 0.07, 'window_size': 95, 'poly_order': 3, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 98, 'rf_max_depth_option': 'Specify', 'rf_max_depth': 2}. Best is trial 10 with value: 0.5918066754371065.
# [I 2024-04-17 23:25:54,823] Trial 33 finished with value: 0.568404085615328 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 1000000000, 'p': 0.067, 'window_size': 84, 'poly_order': 4, 'classifier': 'ExtraTrees', 'et_criterion': 'entropy', 'et_n_estimators': 38, 'et_max_depth_option': None}. Best is trial 10 with value: 0.5918066754371065.
# [I 2024-04-17 23:25:57,026] Trial 35 finished with value: 0.5753798297012711 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 1000000000, 'p': 0.077, 'window_size': 82, 'poly_order': 3, 'classifier': 'ExtraTrees', 'et_criterion': 'entropy', 'et_n_estimators': 39, 'et_max_depth_option': None}. Best is trial 10 with value: 0.5918066754371065.
# [I 2024-04-17 23:25:57,104] Trial 31 finished with value: 0.39540889661473566 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 1000000000, 'p': 0.076, 'window_size': 84, 'poly_order': 2, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 97, 'rf_max_depth_option': 'Specify', 'rf_max_depth': 2}. Best is trial 10 with value: 0.5918066754371065.
# [I 2024-04-17 23:26:01,098] Trial 36 finished with value: 0.5744073428554646 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 1000000000, 'p': 0.081, 'window_size': 87, 'poly_order': 3, 'classifier': 'ExtraTrees', 'et_criterion': 'entropy', 'et_n_estimators': 39, 'et_max_depth_option': None}. Best is trial 10 with value: 0.5918066754371065.
# [I 2024-04-17 23:28:39,752] Trial 48 finished with value: 0.500914811152305 and parameters: {'despike': False, 'baseline_correct': False, 'smoothing': True, 'scaling': False, 'window_size': 40, 'poly_order': 4, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 80, 'rf_max_depth_option': None}. Best is trial 10 with value: 0.5918066754371065.
# [I 2024-04-17 23:28:48,751] Trial 37 finished with value: 0.5709498547322521 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 1000000000, 'p': 0.076, 'window_size': 89, 'poly_order': 2, 'classifier': 'ExtraTrees', 'et_criterion': 'entropy', 'et_n_estimators': 40, 'et_max_depth_option': None}. Best is trial 10 with value: 0.5918066754371065.
# [I 2024-04-17 23:29:15,404] Trial 38 finished with value: 0.41586726555543824 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 1000000000, 'p': 0.081, 'window_size': 66, 'poly_order': 2, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 100, 'rf_max_depth_option': 'Specify', 'rf_max_depth': 2}. Best is trial 10 with value: 0.5918066754371065.
# [I 2024-04-17 23:29:16,644] Trial 39 finished with value: 0.40411365120041653 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 1000000000, 'p': 0.076, 'window_size': 73, 'poly_order': 2, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 86, 'rf_max_depth_option': 'Specify', 'rf_max_depth': 2}. Best is trial 10 with value: 0.5918066754371065.
# [I 2024-04-17 23:30:01,449] Trial 41 finished with value: 0.5781420015980421 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 100000000, 'p': 0.082, 'window_size': 61, 'poly_order': 3, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 80, 'rf_max_depth_option': 'Specify', 'rf_max_depth': 9}. Best is trial 10 with value: 0.5918066754371065.
# [I 2024-04-17 23:30:10,999] Trial 40 finished with value: 0.5693174731431228 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 100000000, 'p': 0.078, 'window_size': 60, 'poly_order': 3, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 80, 'rf_max_depth_option': None}. Best is trial 10 with value: 0.5918066754371065.
# [I 2024-04-17 23:30:13,180] Trial 43 finished with value: 0.5713749225189708 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 100000000, 'p': 0.079, 'window_size': 48, 'poly_order': 3, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 81, 'rf_max_depth_option': 'Specify', 'rf_max_depth': 10}. Best is trial 10 with value: 0.5918066754371065.
# [I 2024-04-17 23:30:14,953] Trial 42 finished with value: 0.5983979629145538 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 1000000000, 'p': 0.081, 'window_size': 65, 'poly_order': 3, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 81, 'rf_max_depth_option': 'Specify', 'rf_max_depth': 11}. Best is trial 42 with value: 0.5983979629145538.
# [I 2024-04-17 23:30:15,294] Trial 44 finished with value: 0.5741752178196013 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 100000000, 'p': 0.081, 'window_size': 45, 'poly_order': 3, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 82, 'rf_max_depth_option': 'Specify', 'rf_max_depth': 10}. Best is trial 42 with value: 0.5983979629145538.
# [I 2024-04-17 23:30:17,860] Trial 46 finished with value: 0.5672247772326545 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 100000000, 'p': 0.083, 'window_size': 50, 'poly_order': 2, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 81, 'rf_max_depth_option': 'Specify', 'rf_max_depth': 11}. Best is trial 42 with value: 0.5983979629145538.
# [I 2024-04-17 23:30:18,260] Trial 45 finished with value: 0.6047945434364621 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 1000000000, 'p': 0.083, 'window_size': 49, 'poly_order': 3, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 84, 'rf_max_depth_option': 'Specify', 'rf_max_depth': 10}. Best is trial 45 with value: 0.6047945434364621.
# [I 2024-04-17 23:30:23,003] Trial 50 finished with value: 0.47277896586713564 and parameters: {'despike': False, 'baseline_correct': False, 'smoothing': True, 'scaling': False, 'window_size': 121, 'poly_order': 4, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 87, 'rf_max_depth_option': 'Specify', 'rf_max_depth': 10}. Best is trial 45 with value: 0.6047945434364621.
# [I 2024-04-17 23:30:26,365] Trial 47 finished with value: 0.5907280077885531 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 100000000, 'p': 0.082, 'window_size': 41, 'poly_order': 4, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 81, 'rf_max_depth_option': None}. Best is trial 45 with value: 0.6047945434364621.
# [I 2024-04-17 23:30:34,546] Trial 49 finished with value: 0.5566882534051647 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 100000000, 'p': 0.057, 'window_size': 127, 'poly_order': 2, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 85, 'rf_max_depth_option': 'Specify', 'rf_max_depth': 10}. Best is trial 45 with value: 0.6047945434364621.
# [I 2024-04-17 23:31:10,685] Trial 51 finished with value: 0.5022531350876757 and parameters: {'despike': False, 'baseline_correct': False, 'smoothing': True, 'scaling': False, 'window_size': 129, 'poly_order': 4, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 87, 'rf_max_depth_option': None}. Best is trial 45 with value: 0.6047945434364621.
# [I 2024-04-17 23:32:01,877] Trial 52 finished with value: 0.4733335668562946 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 100000000, 'p': 0.060000000000000005, 'window_size': 119, 'poly_order': 5, 'classifier': 'SVC', 'svc_c': 3.6355188417893564e-09, 'svc_kernel': 'poly', 'svc_gamma': 'auto'}. Best is trial 45 with value: 0.6047945434364621.
# [I 2024-04-17 23:32:09,966] Trial 53 finished with value: 0.5640113808525511 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 100000000, 'p': 0.08700000000000001, 'window_size': 118, 'poly_order': 4, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 76, 'rf_max_depth_option': 'Specify', 'rf_max_depth': 10}. Best is trial 45 with value: 0.6047945434364621.
# [I 2024-04-17 23:36:33,344] Trial 55 finished with value: 0.1221034513995833 and parameters: {'despike': False, 'baseline_correct': False, 'smoothing': True, 'scaling': False, 'window_size': 116, 'poly_order': 4, 'classifier': 'SVC', 'svc_c': 1.0398033566282347e-10, 'svc_kernel': 'sigmoid', 'svc_gamma': 'auto'}. Best is trial 45 with value: 0.6047945434364621.
# [I 2024-04-17 23:36:44,846] Trial 58 finished with value: 0.1221034513995833 and parameters: {'despike': False, 'baseline_correct': False, 'smoothing': True, 'scaling': False, 'window_size': 122, 'poly_order': 4, 'classifier': 'SVC', 'svc_c': 1.1380075446915202e-10, 'svc_kernel': 'sigmoid', 'svc_gamma': 'auto'}. Best is trial 45 with value: 0.6047945434364621.
# [I 2024-04-17 23:37:00,133] Trial 60 finished with value: 0.14746518553089238 and parameters: {'despike': False, 'baseline_correct': False, 'smoothing': True, 'scaling': True, 'window_size': 17, 'poly_order': 4, 'scaling_type': 'snv', 'classifier': 'SVC', 'svc_c': 4.2472219398437856e-10, 'svc_kernel': 'poly', 'svc_gamma': 'auto'}. Best is trial 45 with value: 0.6047945434364621.
# [I 2024-04-17 23:37:00,304] Trial 61 finished with value: 0.14804182022517415 and parameters: {'despike': False, 'baseline_correct': False, 'smoothing': True, 'scaling': True, 'window_size': 22, 'poly_order': 1, 'scaling_type': 'snv', 'classifier': 'SVC', 'svc_c': 2.2964271400682618e-10, 'svc_kernel': 'poly', 'svc_gamma': 'auto'}. Best is trial 45 with value: 0.6047945434364621.
# [I 2024-04-17 23:37:17,228] Trial 62 finished with value: 0.1221034513995833 and parameters: {'despike': False, 'baseline_correct': False, 'smoothing': True, 'scaling': False, 'window_size': 29, 'poly_order': 4, 'classifier': 'SVC', 'svc_c': 3.453746517102214e-10, 'svc_kernel': 'sigmoid', 'svc_gamma': 'auto'}. Best is trial 45 with value: 0.6047945434364621.
# [I 2024-04-17 23:37:39,056] Trial 63 finished with value: 0.15073785763296113 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': True, 'lam': 10000000, 'p': 0.089, 'window_size': 29, 'poly_order': 4, 'scaling_type': 'snv', 'classifier': 'SVC', 'svc_c': 6.133936930973205e-09, 'svc_kernel': 'sigmoid', 'svc_gamma': 'auto'}. Best is trial 45 with value: 0.6047945434364621.
# [I 2024-04-17 23:37:52,770] Trial 65 finished with value: 0.16544535690923978 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': True, 'lam': 10000000000, 'p': 0.092, 'window_size': 27, 'poly_order': 4, 'scaling_type': 'snv', 'classifier': 'SVC', 'svc_c': 5.991591991221754e-10, 'svc_kernel': 'sigmoid', 'svc_gamma': 'scale'}. Best is trial 45 with value: 0.6047945434364621.
# [I 2024-04-17 23:37:53,461] Trial 64 finished with value: 0.15073785763296113 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': True, 'lam': 10000000, 'p': 0.089, 'window_size': 29, 'poly_order': 4, 'scaling_type': 'snv', 'classifier': 'SVC', 'svc_c': 1.3546119662104005e-10, 'svc_kernel': 'sigmoid', 'svc_gamma': 'auto'}. Best is trial 45 with value: 0.6047945434364621.
# [I 2024-04-17 23:39:27,753] Trial 66 finished with value: 0.5411852715426486 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': False, 'scaling': True, 'lam': 10000000, 'p': 0.093, 'scaling_type': 'snv', 'classifier': 'SVC', 'svc_c': 3953146656.0644064, 'svc_kernel': 'poly', 'svc_gamma': 'scale'}. Best is trial 45 with value: 0.6047945434364621.
# [I 2024-04-17 23:42:01,944] Trial 67 finished with value: 0.5219023482408376 and parameters: {'despike': True, 'baseline_correct': True, 'smoothing': False, 'scaling': True, 'despike_ma': 143, 'despike_threshold': 5.6, 'lam': 10000000000, 'p': 0.091, 'scaling_type': 'snv', 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 11, 'rf_max_depth_option': None}. Best is trial 45 with value: 0.6047945434364621.
# [I 2024-04-17 23:43:01,894] Trial 70 finished with value: 0.5812255433652507 and parameters: {'despike': True, 'baseline_correct': True, 'smoothing': False, 'scaling': False, 'despike_ma': 150, 'despike_threshold': 5.5, 'lam': 10000000000, 'p': 0.092, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 72, 'rf_max_depth_option': None}. Best is trial 45 with value: 0.6047945434364621.
# [I 2024-04-17 23:43:04,736] Trial 69 finished with value: 0.5697201051876648 and parameters: {'despike': True, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'despike_ma': 142, 'despike_threshold': 5.300000000000001, 'lam': 10000000, 'p': 0.093, 'window_size': 32, 'poly_order': 3, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 70, 'rf_max_depth_option': None}. Best is trial 45 with value: 0.6047945434364621.
# [I 2024-04-17 23:43:07,350] Trial 71 finished with value: 0.5808745569883483 and parameters: {'despike': True, 'baseline_correct': True, 'smoothing': False, 'scaling': False, 'despike_ma': 142, 'despike_threshold': 5.300000000000001, 'lam': 10000000000, 'p': 0.093, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 74, 'rf_max_depth_option': None}. Best is trial 45 with value: 0.6047945434364621.
# [I 2024-04-17 23:43:14,892] Trial 72 finished with value: 0.44731980089786527 and parameters: {'despike': True, 'baseline_correct': True, 'smoothing': False, 'scaling': False, 'despike_ma': 153, 'despike_threshold': 5.2, 'lam': 100, 'p': 0.037000000000000005, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 72, 'rf_max_depth_option': None}. Best is trial 45 with value: 0.6047945434364621.
# [I 2024-04-17 23:43:18,173] Trial 68 finished with value: 0.5744766534324699 and parameters: {'despike': True, 'baseline_correct': True, 'smoothing': False, 'scaling': True, 'despike_ma': 147, 'despike_threshold': 5.4, 'lam': 10000000000, 'p': 0.089, 'scaling_type': 'snv', 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 71, 'rf_max_depth_option': None}. Best is trial 45 with value: 0.6047945434364621.
# [I 2024-04-17 23:43:21,027] Trial 74 finished with value: 0.45872583219977325 and parameters: {'despike': True, 'baseline_correct': True, 'smoothing': False, 'scaling': False, 'despike_ma': 150, 'despike_threshold': 5.9, 'lam': 100, 'p': 0.04, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 72, 'rf_max_depth_option': None}. Best is trial 45 with value: 0.6047945434364621.
# [I 2024-04-17 23:43:43,271] Trial 73 finished with value: 0.4370790789939953 and parameters: {'despike': True, 'baseline_correct': True, 'smoothing': False, 'scaling': False, 'despike_ma': 146, 'despike_threshold': 5.5, 'lam': 100, 'p': 0.094, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 90, 'rf_max_depth_option': None}. Best is trial 45 with value: 0.6047945434364621.
# [I 2024-04-17 23:44:37,388] Trial 75 finished with value: 0.4716012318226451 and parameters: {'despike': True, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'despike_ma': 152, 'despike_threshold': 5.1, 'lam': 100, 'p': 0.039, 'window_size': 179, 'poly_order': 5, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 72, 'rf_max_depth_option': None}. Best is trial 45 with value: 0.6047945434364621.
# [I 2024-04-17 23:48:54,326] Trial 78 finished with value: 0.46025214543775095 and parameters: {'despike': True, 'baseline_correct': True, 'smoothing': False, 'scaling': False, 'despike_ma': 173, 'despike_threshold': 6.800000000000001, 'lam': 100, 'p': 0.033, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 60, 'rf_max_depth_option': None}. Best is trial 45 with value: 0.6047945434364621.
# [I 2024-04-17 23:49:08,227] Trial 76 finished with value: 0.4363714875369481 and parameters: {'despike': True, 'baseline_correct': True, 'smoothing': False, 'scaling': False, 'despike_ma': 154, 'despike_threshold': 5.1, 'lam': 100, 'p': 0.08600000000000001, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 70, 'rf_max_depth_option': None}. Best is trial 45 with value: 0.6047945434364621.
# [I 2024-04-17 23:49:10,041] Trial 77 finished with value: 0.4628857547671953 and parameters: {'despike': True, 'baseline_correct': True, 'smoothing': False, 'scaling': False, 'despike_ma': 168, 'despike_threshold': 4.9, 'lam': 100, 'p': 0.035, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 73, 'rf_max_depth_option': None}. Best is trial 45 with value: 0.6047945434364621.
# [I 2024-04-17 23:49:27,458] Trial 82 finished with value: 0.46539174194052546 and parameters: {'despike': True, 'baseline_correct': True, 'smoothing': False, 'scaling': False, 'despike_ma': 174, 'despike_threshold': 7.1000000000000005, 'lam': 1000, 'p': 0.096, 'classifier': 'RandomForest', 'rf_criterion': 'entropy', 'rf_n_estimators': 52, 'rf_max_depth_option': None}. Best is trial 45 with value: 0.6047945434364621.
# [I 2024-04-17 23:49:38,570] Trial 80 finished with value: 0.46547706759028473 and parameters: {'despike': True, 'baseline_correct': True, 'smoothing': False, 'scaling': False, 'despike_ma': 174, 'despike_threshold': 7.1000000000000005, 'lam': 10000, 'p': 0.085, 'classifier': 'RandomForest', 'rf_criterion': 'entropy', 'rf_n_estimators': 61, 'rf_max_depth_option': None}. Best is trial 45 with value: 0.6047945434364621.
# [I 2024-04-17 23:49:48,338] Trial 81 finished with value: 0.4718522107748795 and parameters: {'despike': True, 'baseline_correct': True, 'smoothing': False, 'scaling': False, 'despike_ma': 179, 'despike_threshold': 6.9, 'lam': 1000, 'p': 0.099, 'classifier': 'RandomForest', 'rf_criterion': 'entropy', 'rf_n_estimators': 62, 'rf_max_depth_option': None}. Best is trial 45 with value: 0.6047945434364621.
# [I 2024-04-17 23:49:51,391] Trial 83 finished with value: 0.46591549984955893 and parameters: {'despike': True, 'baseline_correct': True, 'smoothing': False, 'scaling': False, 'despike_ma': 177, 'despike_threshold': 6.800000000000001, 'lam': 1000, 'p': 0.098, 'classifier': 'RandomForest', 'rf_criterion': 'entropy', 'rf_n_estimators': 64, 'rf_max_depth_option': None}. Best is trial 45 with value: 0.6047945434364621.
# [I 2024-04-17 23:50:33,634] Trial 79 finished with value: 0.4684546447290566 and parameters: {'despike': True, 'baseline_correct': True, 'smoothing': False, 'scaling': False, 'despike_ma': 5, 'despike_threshold': 6.9, 'lam': 1000, 'p': 0.097, 'classifier': 'RandomForest', 'rf_criterion': 'entropy', 'rf_n_estimators': 91, 'rf_max_depth_option': None}. Best is trial 45 with value: 0.6047945434364621.
# [I 2024-04-17 23:52:23,337] Trial 90 finished with value: 0.3632308443068968 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 100000000000, 'p': 0.085, 'window_size': 11, 'poly_order': 3, 'classifier': 'ExtraTrees', 'et_criterion': 'gini', 'et_n_estimators': 77, 'et_max_depth_option': 'Specify', 'et_max_depth': 2}. Best is trial 45 with value: 0.6047945434364621.
# [I 2024-04-17 23:52:26,976] Trial 91 finished with value: 0.35764404598093746 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 100000000000, 'p': 0.07200000000000001, 'window_size': 107, 'poly_order': 3, 'classifier': 'ExtraTrees', 'et_criterion': 'gini', 'et_n_estimators': 79, 'et_max_depth_option': 'Specify', 'et_max_depth': 2}. Best is trial 45 with value: 0.6047945434364621.
# [I 2024-04-17 23:53:53,547] Trial 89 finished with value: 0.5636480122916977 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': False, 'scaling': False, 'lam': 100000000000, 'p': 0.07100000000000001, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 92, 'rf_max_depth_option': None}. Best is trial 45 with value: 0.6047945434364621.
# [I 2024-04-17 23:54:14,400] Trial 86 finished with value: 0.4768517609308679 and parameters: {'despike': True, 'baseline_correct': True, 'smoothing': False, 'scaling': False, 'despike_ma': 121, 'despike_threshold': 4.5, 'lam': 10000, 'p': 0.098, 'classifier': 'RandomForest', 'rf_criterion': 'entropy', 'rf_n_estimators': 64, 'rf_max_depth_option': None}. Best is trial 45 with value: 0.6047945434364621.
# [I 2024-04-17 23:54:16,231] Trial 92 finished with value: 0.5727359210966936 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 10000000000, 'p': 0.07200000000000001, 'window_size': 153, 'poly_order': 5, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 92, 'rf_max_depth_option': 'Specify', 'rf_max_depth': 16}. Best is trial 45 with value: 0.6047945434364621.
# [I 2024-04-17 23:54:16,552] Trial 85 finished with value: 0.4604462422557841 and parameters: {'despike': True, 'baseline_correct': True, 'smoothing': False, 'scaling': False, 'despike_ma': 120, 'despike_threshold': 4.5, 'lam': 1000, 'p': 0.098, 'classifier': 'RandomForest', 'rf_criterion': 'entropy', 'rf_n_estimators': 62, 'rf_max_depth_option': None}. Best is trial 45 with value: 0.6047945434364621.
# [I 2024-04-17 23:54:20,802] Trial 93 finished with value: 0.5835806783843661 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 10000000000, 'p': 0.064, 'window_size': 70, 'poly_order': 5, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 93, 'rf_max_depth_option': 'Specify', 'rf_max_depth': 16}. Best is trial 45 with value: 0.6047945434364621.
# [I 2024-04-17 23:54:42,613] Trial 88 finished with value: 0.5686345194595315 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': False, 'scaling': False, 'lam': 100000000000, 'p': 0.07200000000000001, 'classifier': 'RandomForest', 'rf_criterion': 'entropy', 'rf_n_estimators': 93, 'rf_max_depth_option': None}. Best is trial 45 with value: 0.6047945434364621.
# [I 2024-04-17 23:55:05,262] Trial 84 finished with value: 0.47342621740494906 and parameters: {'despike': True, 'baseline_correct': True, 'smoothing': False, 'scaling': False, 'despike_ma': 121, 'despike_threshold': 4.3, 'lam': 1000, 'p': 0.099, 'classifier': 'RandomForest', 'rf_criterion': 'entropy', 'rf_n_estimators': 92, 'rf_max_depth_option': None}. Best is trial 45 with value: 0.6047945434364621.
# [I 2024-04-17 23:55:05,377] Trial 87 finished with value: 0.4877855270176389 and parameters: {'despike': True, 'baseline_correct': True, 'smoothing': False, 'scaling': False, 'despike_ma': 121, 'despike_threshold': 4.2, 'lam': 10000, 'p': 0.098, 'classifier': 'RandomForest', 'rf_criterion': 'entropy', 'rf_n_estimators': 92, 'rf_max_depth_option': None}. Best is trial 45 with value: 0.6047945434364621.
# [I 2024-04-17 23:55:44,778] Trial 94 finished with value: 0.5684109257672503 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 10000000000, 'p': 0.064, 'window_size': 149, 'poly_order': 5, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 95, 'rf_max_depth_option': 'Specify', 'rf_max_depth': 16}. Best is trial 45 with value: 0.6047945434364621.
# [I 2024-04-17 23:55:57,068] Trial 96 finished with value: 0.572045795344897 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 1000000000, 'p': 0.063, 'window_size': 207, 'poly_order': 5, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 76, 'rf_max_depth_option': 'Specify', 'rf_max_depth': 6}. Best is trial 45 with value: 0.6047945434364621.
# [I 2024-04-17 23:56:10,357] Trial 97 finished with value: 0.5720228234041602 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 1000000000, 'p': 0.062, 'window_size': 163, 'poly_order': 5, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 95, 'rf_max_depth_option': 'Specify', 'rf_max_depth': 6}. Best is trial 45 with value: 0.6047945434364621.
# [I 2024-04-17 23:56:26,512] Trial 98 finished with value: 0.5696943672123844 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 10000000000, 'p': 0.075, 'window_size': 55, 'poly_order': 1, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 76, 'rf_max_depth_option': 'Specify', 'rf_max_depth': 23}. Best is trial 45 with value: 0.6047945434364621.
# [I 2024-04-17 23:56:38,336] Trial 95 finished with value: 0.5669398488806181 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 10000000000, 'p': 0.055, 'window_size': 148, 'poly_order': 5, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 95, 'rf_max_depth_option': 'Specify', 'rf_max_depth': 18}. Best is trial 45 with value: 0.6047945434364621.
# [I 2024-04-17 23:56:41,778] Trial 99 finished with value: 0.5414423550306492 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 10000000000, 'p': 0.029, 'window_size': 74, 'poly_order': 1, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 77, 'rf_max_depth_option': 'Specify', 'rf_max_depth': 23}. Best is trial 45 with value: 0.6047945434364621.
# [I 2024-04-17 23:56:43,396] Trial 105 finished with value: 0.396176058432489 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 100000, 'p': 0.044000000000000004, 'window_size': 72, 'poly_order': 5, 'classifier': 'ExtraTrees', 'et_criterion': 'gini', 'et_n_estimators': 73, 'et_max_depth_option': 'Specify', 'et_max_depth': 4}. Best is trial 45 with value: 0.6047945434364621.
# [I 2024-04-17 23:56:55,467] Trial 101 finished with value: 0.5819187067990261 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 10000000000, 'p': 0.066, 'window_size': 74, 'poly_order': 5, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 77, 'rf_max_depth_option': 'Specify', 'rf_max_depth': 21}. Best is trial 45 with value: 0.6047945434364621.
# [I 2024-04-17 23:57:09,042] Trial 106 finished with value: 0.39998244072583083 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 100000, 'p': 0.059000000000000004, 'window_size': 71, 'poly_order': 5, 'classifier': 'ExtraTrees', 'et_criterion': 'gini', 'et_n_estimators': 71, 'et_max_depth_option': 'Specify', 'et_max_depth': 4}. Best is trial 45 with value: 0.6047945434364621.
# [I 2024-04-17 23:57:15,553] Trial 102 finished with value: 0.6029501537735981 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 1000000000, 'p': 0.055, 'window_size': 71, 'poly_order': 5, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 76, 'rf_max_depth_option': 'Specify', 'rf_max_depth': 23}. Best is trial 45 with value: 0.6047945434364621.
# [I 2024-04-17 23:57:16,470] Trial 100 finished with value: 0.5716251874363621 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 10000000000, 'p': 0.055, 'window_size': 55, 'poly_order': 5, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 96, 'rf_max_depth_option': 'Specify', 'rf_max_depth': 23}. Best is trial 45 with value: 0.6047945434364621.
# [I 2024-04-17 23:57:25,433] Trial 107 finished with value: 0.3952630244344298 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 100000, 'p': 0.044000000000000004, 'window_size': 66, 'poly_order': 5, 'classifier': 'ExtraTrees', 'et_criterion': 'gini', 'et_n_estimators': 70, 'et_max_depth_option': 'Specify', 'et_max_depth': 4}. Best is trial 45 with value: 0.6047945434364621.
# [I 2024-04-17 23:57:48,904] Trial 104 finished with value: 0.5490913461237165 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 100000, 'p': 0.068, 'window_size': 75, 'poly_order': 5, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 84, 'rf_max_depth_option': 'Specify', 'rf_max_depth': 25}. Best is trial 45 with value: 0.6047945434364621.
# [I 2024-04-17 23:57:50,348] Trial 103 finished with value: 0.6015434100701798 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 1000000000, 'p': 0.054, 'window_size': 69, 'poly_order': 5, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 100, 'rf_max_depth_option': 'Specify', 'rf_max_depth': 22}. Best is trial 45 with value: 0.6047945434364621.
# [I 2024-04-17 23:58:44,825] Trial 108 finished with value: 0.594482691938368 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 1000000000, 'p': 0.079, 'window_size': 38, 'poly_order': 5, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 84, 'rf_max_depth_option': 'Specify', 'rf_max_depth': 13}. Best is trial 45 with value: 0.6047945434364621.
# [I 2024-04-17 23:59:07,907] Trial 109 finished with value: 0.6026721105958287 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 1000000000, 'p': 0.068, 'window_size': 40, 'poly_order': 3, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 84, 'rf_max_depth_option': 'Specify', 'rf_max_depth': 14}. Best is trial 45 with value: 0.6047945434364621.
# [I 2024-04-17 23:59:27,967] Trial 110 finished with value: 0.5692125305317407 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 1000000, 'p': 0.067, 'window_size': 42, 'poly_order': 3, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 84, 'rf_max_depth_option': 'Specify', 'rf_max_depth': 13}. Best is trial 45 with value: 0.6047945434364621.
# [I 2024-04-17 23:59:35,768] Trial 111 finished with value: 0.5981109950892237 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 1000000000, 'p': 0.067, 'window_size': 62, 'poly_order': 5, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 84, 'rf_max_depth_option': 'Specify', 'rf_max_depth': 13}. Best is trial 45 with value: 0.6047945434364621.
# [I 2024-04-17 23:59:38,081] Trial 112 finished with value: 0.5912480460083024 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 1000000000, 'p': 0.067, 'window_size': 37, 'poly_order': 5, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 85, 'rf_max_depth_option': 'Specify', 'rf_max_depth': 13}. Best is trial 45 with value: 0.6047945434364621.
# [I 2024-04-17 23:59:44,326] Trial 113 finished with value: 0.6038291370488393 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 1000000000, 'p': 0.067, 'window_size': 42, 'poly_order': 5, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 84, 'rf_max_depth_option': 'Specify', 'rf_max_depth': 14}. Best is trial 45 with value: 0.6047945434364621.
# [I 2024-04-17 23:59:58,224] Trial 115 finished with value: 0.6030859085260049 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 1000000000, 'p': 0.054, 'window_size': 41, 'poly_order': 5, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 88, 'rf_max_depth_option': 'Specify', 'rf_max_depth': 13}. Best is trial 45 with value: 0.6047945434364621.
# [I 2024-04-17 23:59:58,960] Trial 114 finished with value: 0.5948454352641442 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 1000000000, 'p': 0.066, 'window_size': 105, 'poly_order': 3, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 88, 'rf_max_depth_option': 'Specify', 'rf_max_depth': 13}. Best is trial 45 with value: 0.6047945434364621.
# [I 2024-04-18 00:00:21,530] Trial 116 finished with value: 0.6045188901840508 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 1000000000, 'p': 0.079, 'window_size': 40, 'poly_order': 5, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 84, 'rf_max_depth_option': 'Specify', 'rf_max_depth': 13}. Best is trial 45 with value: 0.6047945434364621.
# [I 2024-04-18 00:00:50,988] Trial 117 finished with value: 0.6069130923049418 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 1000000000, 'p': 0.052000000000000005, 'window_size': 39, 'poly_order': 3, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 89, 'rf_max_depth_option': 'Specify', 'rf_max_depth': 13}. Best is trial 117 with value: 0.6069130923049418.
# [I 2024-04-18 00:01:21,083] Trial 118 finished with value: 0.5945164775297391 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 1000000000, 'p': 0.052000000000000005, 'window_size': 64, 'poly_order': 3, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 100, 'rf_max_depth_option': 'Specify', 'rf_max_depth': 13}. Best is trial 117 with value: 0.6069130923049418.
# ...
# [I 2024-04-18 02:01:55,808] Trial 463 finished with value: 0.608407999375214 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 1000000000, 'p': 0.055, 'window_size': 46, 'poly_order': 3, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 100, 'rf_max_depth_option': 'Specify', 'rf_max_depth': 21}. Best is trial 129 with value: 0.6158318528030404.
# [I 2024-04-18 02:01:59,353] Trial 464 finished with value: 0.5633139181078433 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 1000000000, 'p': 0.006, 'window_size': 44, 'poly_order': 3, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 93, 'rf_max_depth_option': 'Specify', 'rf_max_depth': 21}. Best is trial 129 with value: 0.6158318528030404.
# [I 2024-04-18 02:02:56,747] Trial 468 finished with value: 0.2036233528186818 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 1000000000, 'p': 0.054, 'window_size': 52, 'poly_order': 3, 'classifier': 'SVC', 'svc_c': 0.05797542019980388, 'svc_kernel': 'poly', 'svc_gamma': 'scale'}. Best is trial 129 with value: 0.6158318528030404.
# [I 2024-04-18 02:02:57,120] Trial 466 finished with value: 0.5843664648890987 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 1000000000, 'p': 0.056, 'window_size': 51, 'poly_order': 3, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 100, 'rf_max_depth_option': 'Specify', 'rf_max_depth': 32}. Best is trial 129 with value: 0.6158318528030404.
# [I 2024-04-18 02:03:07,573] Trial 467 finished with value: 0.6015124180701718 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 1000000000, 'p': 0.063, 'window_size': 52, 'poly_order': 3, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 93, 'rf_max_depth_option': 'Specify', 'rf_max_depth': 32}. Best is trial 129 with value: 0.6158318528030404.
# [I 2024-04-18 02:03:31,373] Trial 469 finished with value: 0.6123583032630344 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 1000000000, 'p': 0.063, 'window_size': 49, 'poly_order': 3, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 93, 'rf_max_depth_option': 'Specify', 'rf_max_depth': 21}. Best is trial 129 with value: 0.6158318528030404.
# [I 2024-04-18 02:03:45,170] Trial 470 finished with value: 0.601666826198928 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 1000000000, 'p': 0.051000000000000004, 'window_size': 50, 'poly_order': 3, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 100, 'rf_max_depth_option': 'Specify', 'rf_max_depth': 30}. Best is trial 129 with value: 0.6158318528030404.
# [I 2024-04-18 02:04:02,188] Trial 471 finished with value: 0.5898568729464321 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 1000000000, 'p': 0.052000000000000005, 'window_size': 123, 'poly_order': 3, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 100, 'rf_max_depth_option': 'Specify', 'rf_max_depth': 22}. Best is trial 129 with value: 0.6158318528030404.
# [I 2024-04-18 02:04:04,204] Trial 472 finished with value: 0.6017456501168381 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 1000000000, 'p': 0.052000000000000005, 'window_size': 51, 'poly_order': 3, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 98, 'rf_max_depth_option': 'Specify', 'rf_max_depth': 22}. Best is trial 129 with value: 0.6158318528030404.
# [I 2024-04-18 02:04:19,383] Trial 479 finished with value: 0.5166894550422167 and parameters: {'despike': False, 'baseline_correct': False, 'smoothing': False, 'scaling': False, 'classifier': 'ExtraTrees', 'et_criterion': 'entropy', 'et_n_estimators': 48, 'et_max_depth_option': None}. Best is trial 129 with value: 0.6158318528030404.
# [I 2024-04-18 02:05:03,222] Trial 473 finished with value: 0.6032413389316534 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 1000000000, 'p': 0.056, 'window_size': 33, 'poly_order': 3, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 100, 'rf_max_depth_option': 'Specify', 'rf_max_depth': 13}. Best is trial 129 with value: 0.6158318528030404.
# [I 2024-04-18 02:05:08,990] Trial 474 finished with value: 0.6000872968466295 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 1000000000, 'p': 0.052000000000000005, 'window_size': 35, 'poly_order': 3, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 100, 'rf_max_depth_option': 'Specify', 'rf_max_depth': 21}. Best is trial 129 with value: 0.6158318528030404.
# [I 2024-04-18 02:05:13,328] Trial 475 finished with value: 0.5943076508834877 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 1000000000, 'p': 0.054, 'window_size': 38, 'poly_order': 3, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 100, 'rf_max_depth_option': 'Specify', 'rf_max_depth': 20}. Best is trial 129 with value: 0.6158318528030404.
# [I 2024-04-18 02:05:29,785] Trial 477 finished with value: 0.5023957777410109 and parameters: {'despike': False, 'baseline_correct': False, 'smoothing': False, 'scaling': False, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 98, 'rf_max_depth_option': 'Specify', 'rf_max_depth': 22}. Best is trial 129 with value: 0.6158318528030404.
# [I 2024-04-18 02:05:31,751] Trial 476 finished with value: 0.5098888615057218 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': False, 'scaling': False, 'lam': 100000, 'p': 0.052000000000000005, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 100, 'rf_max_depth_option': 'Specify', 'rf_max_depth': 21}. Best is trial 129 with value: 0.6158318528030404.
# [I 2024-04-18 02:05:48,073] Trial 478 finished with value: 0.4998287976027081 and parameters: {'despike': False, 'baseline_correct': False, 'smoothing': False, 'scaling': False, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 98, 'rf_max_depth_option': 'Specify', 'rf_max_depth': 23}. Best is trial 129 with value: 0.6158318528030404.
# [I 2024-04-18 02:06:16,197] Trial 480 finished with value: 0.5401161336549766 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 100000, 'p': 0.035, 'window_size': 59, 'poly_order': 3, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 98, 'rf_max_depth_option': 'Specify', 'rf_max_depth': 22}. Best is trial 129 with value: 0.6158318528030404.
# [I 2024-04-18 02:07:00,213] Trial 481 finished with value: 0.5563477884124215 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 100000, 'p': 0.062, 'window_size': 37, 'poly_order': 3, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 98, 'rf_max_depth_option': 'Specify', 'rf_max_depth': 20}. Best is trial 129 with value: 0.6158318528030404.
# [I 2024-04-18 02:07:12,910] Trial 482 finished with value: 0.5929744067147298 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 1000000000, 'p': 0.066, 'window_size': 70, 'poly_order': 3, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 98, 'rf_max_depth_option': 'Specify', 'rf_max_depth': 20}. Best is trial 129 with value: 0.6158318528030404.
# [I 2024-04-18 02:07:15,876] Trial 483 finished with value: 0.5979648277970532 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 1000000000, 'p': 0.07, 'window_size': 31, 'poly_order': 3, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 98, 'rf_max_depth_option': 'Specify', 'rf_max_depth': 19}. Best is trial 129 with value: 0.6158318528030404.
# [I 2024-04-18 02:07:34,347] Trial 484 finished with value: 0.5465956959755507 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 100000, 'p': 0.066, 'window_size': 32, 'poly_order': 3, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 98, 'rf_max_depth_option': 'Specify', 'rf_max_depth': 20}. Best is trial 129 with value: 0.6158318528030404.
# [I 2024-04-18 02:07:38,797] Trial 485 finished with value: 0.5481860663602967 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 100000000000, 'p': 0.036000000000000004, 'window_size': 17, 'poly_order': 3, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 97, 'rf_max_depth_option': 'Specify', 'rf_max_depth': 19}. Best is trial 129 with value: 0.6158318528030404.
# [I 2024-04-18 02:07:40,446] Trial 486 finished with value: 0.5980726903807361 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 1000000000, 'p': 0.061, 'window_size': 32, 'poly_order': 3, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 94, 'rf_max_depth_option': 'Specify', 'rf_max_depth': 19}. Best is trial 129 with value: 0.6158318528030404.
# [I 2024-04-18 02:07:50,243] Trial 487 finished with value: 0.56238148034206 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 100000000000, 'p': 0.065, 'window_size': 31, 'poly_order': 3, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 77, 'rf_max_depth_option': 'Specify', 'rf_max_depth': 20}. Best is trial 129 with value: 0.6158318528030404.
# [I 2024-04-18 02:08:51,557] Trial 488 finished with value: 0.563455785321345 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 100000000000, 'p': 0.066, 'window_size': 30, 'poly_order': 3, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 94, 'rf_max_depth_option': 'Specify', 'rf_max_depth': 19}. Best is trial 129 with value: 0.6158318528030404.
# [I 2024-04-18 02:09:07,897] Trial 489 finished with value: 0.5987652370910699 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 1000000000, 'p': 0.061, 'window_size': 31, 'poly_order': 3, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 94, 'rf_max_depth_option': 'Specify', 'rf_max_depth': 15}. Best is trial 129 with value: 0.6158318528030404.
# [I 2024-04-18 02:09:12,737] Trial 490 finished with value: 0.5984878723493404 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 1000000000, 'p': 0.061, 'window_size': 46, 'poly_order': 3, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 95, 'rf_max_depth_option': 'Specify', 'rf_max_depth': 26}. Best is trial 129 with value: 0.6158318528030404.
# [I 2024-04-18 02:09:33,537] Trial 491 finished with value: 0.5533829611513845 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 100000000000, 'p': 0.055, 'window_size': 16, 'poly_order': 3, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 95, 'rf_max_depth_option': None}. Best is trial 129 with value: 0.6158318528030404.
# [I 2024-04-18 02:09:56,352] Trial 493 finished with value: 0.6149487278607969 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 1000000000, 'p': 0.055, 'window_size': 45, 'poly_order': 3, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 95, 'rf_max_depth_option': None}. Best is trial 129 with value: 0.6158318528030404.
# [I 2024-04-18 02:09:57,107] Trial 492 finished with value: 0.5980878677379957 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 1000000000, 'p': 0.038, 'window_size': 57, 'poly_order': 3, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 95, 'rf_max_depth_option': None}. Best is trial 129 with value: 0.6158318528030404.
# [I 2024-04-18 02:10:00,322] Trial 494 finished with value: 0.6005674598161136 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 1000000000, 'p': 0.055, 'window_size': 57, 'poly_order': 3, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 95, 'rf_max_depth_option': None}. Best is trial 129 with value: 0.6158318528030404.
# [I 2024-04-18 02:10:46,479] Trial 495 finished with value: 0.6091389361920592 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 1000000000, 'p': 0.055, 'window_size': 59, 'poly_order': 3, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 95, 'rf_max_depth_option': None}. Best is trial 129 with value: 0.6158318528030404.
# [I 2024-04-18 02:10:56,595] Trial 499 finished with value: 0.5476829660909326 and parameters: {'despike': True, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'despike_ma': 8, 'despike_threshold': 7.3, 'lam': 1000000, 'p': 0.057, 'window_size': 58, 'poly_order': 3, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 15, 'rf_max_depth_option': None}. Best is trial 129 with value: 0.6158318528030404.
# [I 2024-04-18 02:11:01,321] Trial 496 finished with value: 0.5653857659477773 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 1000000, 'p': 0.055, 'window_size': 46, 'poly_order': 3, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 92, 'rf_max_depth_option': None}. Best is trial 129 with value: 0.6158318528030404.
# [I 2024-04-18 02:11:05,395] Trial 497 finished with value: 0.5897030971065262 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'lam': 1000000000, 'p': 0.017, 'window_size': 56, 'poly_order': 3, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 92, 'rf_max_depth_option': None}. Best is trial 129 with value: 0.6158318528030404.
# [I 2024-04-18 02:11:53,981] Trial 498 finished with value: 0.5917670704801129 and parameters: {'despike': True, 'baseline_correct': True, 'smoothing': True, 'scaling': False, 'despike_ma': 11, 'despike_threshold': 5.9, 'lam': 1000000000, 'p': 0.038, 'window_size': 59, 'poly_order': 3, 'classifier': 'RandomForest', 'rf_criterion': 'gini', 'rf_n_estimators': 92, 'rf_max_depth_option': None}. Best is trial 129 with value: 0.6158318528030404.
# [I 2024-04-18 04:26:18,627] Trial 181 finished with value: 0.5551939225743249 and parameters: {'despike': False, 'baseline_correct': False, 'smoothing': True, 'scaling': False, 'window_size': 61, 'poly_order': 3, 'classifier': 'SVC', 'svc_c': 2.8176654891171477e-05, 'svc_kernel': 'linear', 'svc_gamma': 'scale'}. Best is trial 129 with value: 0.6158318528030404.
# [I 2024-04-18 04:49:13,023] Trial 59 finished with value: 0.5408075760369052 and parameters: {'despike': False, 'baseline_correct': False, 'smoothing': True, 'scaling': False, 'window_size': 30, 'poly_order': 4, 'classifier': 'SVC', 'svc_c': 1.5349079346366202e-09, 'svc_kernel': 'poly', 'svc_gamma': 'auto'}. Best is trial 129 with value: 0.6158318528030404.

# %%
results_df = study.trials_dataframe(attrs=("number", "value", "params", "state"))
results_df.to_csv("../../data/studies/f1_score_optuna_cleaning_and_model_parameters.csv")

# %%
import joblib

joblib.dump(study, "../../data/studies/f1_score_optuna_cleaning_and_model_parameters.pkl")

# loaded_study = joblib.load("../../data/studies/cleaning_study.pkl")
# print("Best trial until now:")
# print(" Value: ", loaded_study.best_trial.value)
# print(" Params: ")
# for key, value in loaded_study.best_trial.params.items():
#     print(f"    {key}: {value}")

# %%
print(study.best_trial)

# %%
from optuna.visualization import plot_optimization_history, plot_slice

plot_optimization_history(study)

# %%
plot_slice(study)

# %%
optuna.visualization.plot_contour(study)

# %%
optuna.visualization.plot_param_importances(study)

# %% [markdown]
# Continue the study.

# %%
# study.optimize(objective, n_trials=100, n_jobs=-1)

# print(study.best_trial)
