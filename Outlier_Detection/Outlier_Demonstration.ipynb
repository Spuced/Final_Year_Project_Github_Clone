# %% [markdown]
# #### **This is a demonstration of the variance that can occur within the same surface.**

# %% [markdown]
# Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sys
sys.path.append('..')
from Cleaning_and_Evaluation import *

# %% [markdown]
# Read the spectral data

# %%
df = pd.read_csv("../../data/exosomes.raw_spectrum_1.csv")
#df = pd.read_csv("../../data/exosomes.raw_spectrum_400-1800.csv")

# %%
df = df[(df['WaveNumber'] >= 400) & (df['WaveNumber'] <= 1800)]

# %%
df['Scaled_Absorbance'] = df.groupby('SpecID')['Absorbance'].transform(lambda x: snv_normalise(x))

# %%
df
# Out:
#               SpecID   Seq  WaveNumber  Absorbance     SurID         Status  \
# 293      201210-1-00   293   400.22778   1765.6628  201210-1         Normal
# 294      201210-1-00   294   400.91116   1774.7809  201210-1         Normal
# 295      201210-1-00   295   401.59454   1769.0302  201210-1         Normal
# 296      201210-1-00   296   402.27789   1756.4220  201210-1         Normal
# 297      201210-1-00   297   402.96127   1758.8690  201210-1         Normal
# ...              ...   ...         ...         ...       ...            ...
# 8023277  210526-3-09  2337  1797.03870   1617.3926  210526-3  Hyperglycemia
# 8023278  210526-3-09  2338  1797.72200   1633.0911  210526-3  Hyperglycemia
# 8023279  210526-3-09  2339  1798.40550   1633.3076  210526-3  Hyperglycemia
# 8023280  210526-3-09  2340  1799.08890   1641.8665  210526-3  Hyperglycemia
# 8023281  210526-3-09  2341  1799.77220   1618.2405  210526-3  Hyperglycemia
#
#          Scaled_Absorbance
# 293               1.317299
# 294               1.378171
# 295               1.339779
# 296               1.255608
# 297               1.271944
# ...                    ...
# 8023277          -3.024542
# 8023278          -2.937646
# 8023279          -2.936448
# 8023280          -2.889072
# 8023281          -3.019848
#
# [6239205 rows x 7 columns]

# %%
print(df['SurID'].unique())
# Out:
# ['201210-1' '201210-2' '210114-1' '210114-2' '210120-1' '210120-2'
#  '210121-1' '210121-2' '210211-1' '210211-2' '210217-1' '210217-2'
#  '210218-1' '210224-1' '210225-1' '210225-2' '210303-1' '210303-2'
#  '210304-1' '210304-2' '210310-1' '210310-2' '210311-1' '210311-2'
#  '210315-1' '210315-2' '210318-1' '210318-2' '210324-1' '210324-2'
#  '210325-1' '210325-2' '210331-1' '210401-1' '210415-1' '210415-2'
#  '210419-1' '210419-2' '210421-1' '210407-1' '210407-2' '210414-1'
#  '210414-3' '210414-2' '210428-1' '210428-2' '210428-3' '210429-1'
#  '210504-1' '210504-2' '210504-3' '210505-1' '210510-1' '210510-2'
#  '210511-1' '210518-1' '210519-1' '210519-2' '210519-3' '210524-1'
#  '210526-1' '210526-2' '210526-3']

# %% [markdown]
# ---

# %% [markdown]
# #### **This is a Plot of the Spectra on one Surface**

# %%
sns.set_style('whitegrid')

# %%
sample = df[df['SurID'] == "210325-1"]
plt.figure(figsize=(10, 6))
sns.lineplot(x="WaveNumber", y="Absorbance", data=sample, hue='SpecID', legend=None)
# Out:
# <Axes: xlabel='WaveNumber', ylabel='Absorbance'>

# %% [markdown]
# **Now with scaling**

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(x="WaveNumber", y="Scaled_Absorbance", data=sample, hue='SpecID', legend=None)
# Out:
# <Axes: xlabel='WaveNumber', ylabel='Scaled_Absorbance'>

# %% [markdown]
# Lets try another.

# %%
sample = df[df['SurID'] == "201210-1"]
plt.figure(figsize=(10, 6))
sns.lineplot(x="WaveNumber", y="Absorbance", data=sample, hue='SpecID', legend=None)
# Out:
# <Axes: xlabel='WaveNumber', ylabel='Absorbance'>

# %% [markdown]
# **Now with scaling**

# %%
# Now with scaling
plt.figure(figsize=(10, 6))
sns.lineplot(x="WaveNumber", y="Scaled_Absorbance", data=sample, hue='SpecID', legend=None)
# Out:
# <Axes: xlabel='WaveNumber', ylabel='Scaled_Absorbance'>
