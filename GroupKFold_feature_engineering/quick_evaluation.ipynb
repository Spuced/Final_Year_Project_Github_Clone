# %% [markdown]
# #### **This notebook contains the functions used to clean the spectra.**

# %% [markdown]
# Import Libraries

# %%
import pandas as pd
import numpy as np
from scipy.signal import savgol_filter
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold, KFold
import seaborn as sns
from Spectra_Preparation_Functions import *
import matplotlib.pyplot as plt

# %% [markdown]
# Read the spectral data

# %%
# df = pd.read_csv("../../data/exosomes.raw_spectrum_400-1800.csv")
df = pd.read_csv("../../data/400-1800_with_raw_scaled_surface_pagerank.csv")

# %%
df
# Out:
#               SpecID   Seq  WaveNumber  Absorbance     SurID         Status  \
# 0        201210-1-00   293   400.22778   1765.6628  201210-1         Normal
# 1        201210-1-00   294   400.91116   1774.7809  201210-1         Normal
# 2        201210-1-00   295   401.59454   1769.0302  201210-1         Normal
# 3        201210-1-00   296   402.27789   1756.4220  201210-1         Normal
# 4        201210-1-00   297   402.96127   1758.8690  201210-1         Normal
# ...              ...   ...         ...         ...       ...            ...
# 6239200  210526-3-09  2337  1797.03870   1617.3926  210526-3  Hyperglycemia
# 6239201  210526-3-09  2338  1797.72200   1633.0911  210526-3  Hyperglycemia
# 6239202  210526-3-09  2339  1798.40550   1633.3076  210526-3  Hyperglycemia
# 6239203  210526-3-09  2340  1799.08890   1641.8665  210526-3  Hyperglycemia
# 6239204  210526-3-09  2341  1799.77220   1618.2405  210526-3  Hyperglycemia
#
#          PageRank
# 0        1.074427
# 1        1.074427
# 2        1.074427
# 3        1.074427
# 4        1.074427
# ...           ...
# 6239200  1.021165
# 6239201  1.021165
# 6239202  1.021165
# 6239203  1.021165
# 6239204  1.021165
#
# [6239205 rows x 7 columns]

# %% [markdown]
# #### **Select the chosen cleaning parameters then run the functions**

# %% [markdown]
# Choose the Parameters

# %%
# # Best Full Spectrum Parameters

# Optuna Outlier Removed Parameters
pagerank_cutoff = 0.902461
despike_ma = 57
despike_threshold = 3.75
lam = 10 ** 11
p = 0.074
window_size = 51
poly_order = 3

# pagerank_cutoff = 0.902461
# despike_ma = 57
# despike_threshold = 3.75
# lam = 10 ** 8
# p = 0.056
# lam_1 = 10**-4
# window_size = 19
# poly_order = 2

# %% [markdown]
# #### **Here is an example on 1 Spectra**

# %%
sample = df[df['SpecID'] == "201210-2-08"]
sns.set_style('whitegrid')
sns.lineplot(x="WaveNumber", y="Absorbance", data=sample)
# Out:
# <Axes: xlabel='WaveNumber', ylabel='Absorbance'>

# %% [markdown]
# Despike

# %%
sample['Absorbance'] = sample.groupby('SpecID')['Absorbance'].transform(lambda x: despike_group(x, ma=despike_ma, threshold=despike_threshold))
sns.lineplot(x="WaveNumber", y="Absorbance", data=sample)
# Out:
# /tmp/ipykernel_29775/250951349.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample['Absorbance'] = sample.groupby('SpecID')['Absorbance'].transform(lambda x: despike_group(x, ma=despike_ma, threshold=despike_threshold))
# <Axes: xlabel='WaveNumber', ylabel='Absorbance'>

# %% [markdown]
# Baseline Correction

# %%
sample['Baseline'] = sample.groupby('SpecID')['Absorbance'].transform(lambda x: asls_baseline_correction(x, lam=lam, p=p))
#sample['Baseline'] = sample.groupby('SpecID')['Absorbance'].transform(lambda x: iasls_baseline_correction(x, lam=lam, p=p, lam_1=lam_1))

sns.lineplot(x="WaveNumber", y="Absorbance", data=sample)
sns.lineplot(x="WaveNumber", y="Baseline", data=sample)
plt.show()

# Subtract the baseline
sample['Baseline_Corrected_Absorbance'] = sample['Absorbance'] - sample['Baseline']
sns.lineplot(x="WaveNumber", y="Baseline_Corrected_Absorbance", data=sample)
# Out:
# /tmp/ipykernel_29775/2601916869.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample['Baseline'] = sample.groupby('SpecID')['Absorbance'].transform(lambda x: asls_baseline_correction(x, lam=lam, p=p))
# /tmp/ipykernel_29775/2601916869.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample['Baseline_Corrected_Absorbance'] = sample['Absorbance'] - sample['Baseline']
# <Axes: xlabel='WaveNumber', ylabel='Baseline_Corrected_Absorbance'>

# %% [markdown]
# Smoothing Baseline_Corrected_Spectrum

# %%
# Apply Savitzky-Golay filter to smooth the Absorbance values
sample['Smoothed_Absorbance'] = sample.groupby('SpecID')['Baseline_Corrected_Absorbance'].transform(lambda x: savgol_filter(x, window_size, poly_order, deriv=0))
sns.lineplot(x="WaveNumber", y="Smoothed_Absorbance", data=sample)
# Out:
# /tmp/ipykernel_29775/1425479424.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample['Smoothed_Absorbance'] = sample.groupby('SpecID')['Baseline_Corrected_Absorbance'].transform(lambda x: savgol_filter(x, window_size, poly_order, deriv=0))
# <Axes: xlabel='WaveNumber', ylabel='Smoothed_Absorbance'>

# %% [markdown]
# Scale the spectra

# %%
sample['Smoothed_Absorbance'] = sample.groupby('SpecID')['Smoothed_Absorbance'].transform(lambda x: vector_normalise(x))
sns.lineplot(x="WaveNumber", y="Smoothed_Absorbance", data=sample)
# Out:
# /tmp/ipykernel_29775/1189992890.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample['Smoothed_Absorbance'] = sample.groupby('SpecID')['Smoothed_Absorbance'].transform(lambda x: vector_normalise(x))
# <Axes: xlabel='WaveNumber', ylabel='Smoothed_Absorbance'>

# %%
df['Absorbance'] = df.groupby('SpecID')['Absorbance'].transform(lambda x: despike_group(x, ma=despike_ma, threshold=despike_threshold))

# %%
df['Baseline'] = df.groupby('SpecID')['Absorbance'].transform(lambda x: asls_baseline_correction(x, lam=lam, p=p))
#df['Baseline'] = df.groupby('SpecID')['Absorbance'].transform(lambda x: iasls_baseline_correction(x, lam=lam, p=p, lam_1=lam_1))

# %%
df['Absorbance'] = df['Absorbance'] - df['Baseline']

# %%
# df['Absorbance'] = df.groupby('SpecID')['Absorbance'].transform(lambda x: savgol_filter(x, window_size, poly_order, deriv=0))

# %%
# df['Absorbance'] = df.groupby('SpecID')['Absorbance'].transform(lambda x: normalise(x))
df['Absorbance'] = df.groupby('SpecID')['Absorbance'].transform(lambda x: vector_normalise(x))
# df['Absorbance'] = df.groupby('SpecID')['Absorbance'].transform(lambda x: svn_normalise(x))

# %%
df
# Out:
#               SpecID   Seq  WaveNumber  Absorbance     SurID         Status  \
# 0        201210-1-00   293   400.22778   -0.001247  201210-1         Normal
# 1        201210-1-00   294   400.91116    0.001740  201210-1         Normal
# 2        201210-1-00   295   401.59454   -0.000019  201210-1         Normal
# 3        201210-1-00   296   402.27789   -0.003967  201210-1         Normal
# 4        201210-1-00   297   402.96127   -0.003110  201210-1         Normal
# ...              ...   ...         ...         ...       ...            ...
# 6239200  210526-3-09  2337  1797.03870   -0.016926  210526-3  Hyperglycemia
# 6239201  210526-3-09  2338  1797.72200   -0.014938  210526-3  Hyperglycemia
# 6239202  210526-3-09  2339  1798.40550   -0.014875  210526-3  Hyperglycemia
# 6239203  210526-3-09  2340  1799.08890   -0.013774  210526-3  Hyperglycemia
# 6239204  210526-3-09  2341  1799.77220   -0.016672  210526-3  Hyperglycemia
#
#          PageRank     Baseline
# 0        1.074427  1769.569028
# 1        1.074427  1769.330009
# 2        1.074427  1769.090991
# 3        1.074427  1768.851972
# 4        1.074427  1768.612953
# ...           ...          ...
# 6239200  1.021165  1753.639314
# 6239201  1.021165  1753.341720
# 6239202  1.021165  1753.044127
# 6239203  1.021165  1752.746533
# 6239204  1.021165  1752.448939
#
# [6239205 rows x 8 columns]

# %% [markdown]
# #### **This is how the PageRank Filter Affects a Surface**

# %%
raw_df = pd.read_csv("../../data/400-1800_with_raw_scaled_surface_pagerank.csv")

# %%
df['SurID'].unique()
# Out:
# array(['201210-1', '201210-2', '210114-1', '210114-2', '210120-1',
#        '210120-2', '210121-1', '210121-2', '210211-1', '210211-2',
#        '210217-1', '210217-2', '210218-1', '210224-1', '210225-1',
#        '210225-2', '210303-1', '210303-2', '210304-1', '210304-2',
#        '210310-1', '210310-2', '210311-1', '210311-2', '210315-1',
#        '210315-2', '210318-1', '210318-2', '210324-1', '210324-2',
#        '210325-1', '210325-2', '210331-1', '210401-1', '210415-1',
#        '210415-2', '210419-1', '210419-2', '210421-1', '210407-1',
#        '210407-2', '210414-1', '210414-3', '210414-2', '210428-1',
#        '210428-2', '210428-3', '210429-1', '210504-1', '210504-2',
#        '210504-3', '210505-1', '210510-1', '210510-2', '210511-1',
#        '210518-1', '210519-1', '210519-2', '210519-3', '210524-1',
#        '210526-1', '210526-2', '210526-3'], dtype=object)

# %%
SurID = "210324-1"

# %%
surface = raw_df[raw_df['SurID'] == SurID]
print(surface['SpecID'].nunique())
sns.lineplot(x="WaveNumber", y="Absorbance", data=surface, hue='SpecID', legend=None)
# Out:
# 50
# <Axes: xlabel='WaveNumber', ylabel='Absorbance'>

# %%
surface['PageRank'].describe()
# Out:
# count    102450.000000
# mean          0.961240
# std           0.226962
# min           0.314831
# 25%           0.812669
# 50%           1.036151
# 75%           1.109278
# max           1.278702
# Name: PageRank, dtype: float64

# %%
surface = surface[surface['PageRank'] > pagerank_cutoff]
print(surface['SpecID'].nunique())
sns.lineplot(x="WaveNumber", y="Absorbance", data=surface, hue='SpecID', legend=None)
# Out:
# 34
# <Axes: xlabel='WaveNumber', ylabel='Absorbance'>

# %%
surface = df[df['SurID'] == SurID]
print(surface['SpecID'].nunique())
sns.lineplot(x="WaveNumber", y="Absorbance", data=surface, hue='SpecID', legend=None)
# Out:
# 50
# <Axes: xlabel='WaveNumber', ylabel='Absorbance'>

# %%
surface = surface[surface['PageRank'] > pagerank_cutoff]
print(surface['SpecID'].nunique())
sns.lineplot(x="WaveNumber", y="Absorbance", data=surface, hue='SpecID', legend=None)
# Out:
# 34
# <Axes: xlabel='WaveNumber', ylabel='Absorbance'>

# %% [markdown]
# The PageRank Filter Leaves the more representative spectra within a surface

# %% [markdown]
# #### **Machine Learning**

# %%
from sklearn.model_selection import cross_validate, GroupKFold
from sklearn.ensemble import ExtraTreesClassifier, RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_recall_fscore_support
from sklearn.metrics import classification_report

# %%
def evaluate_model(df, model):

    # Set the Surfaces as groups
    groups = df['SurID']
    X = df.drop(['Status', 'SurID'], axis=1)
    y = df['Status']
    
    # Using GroupKFold for classification tasks
    cv = GroupKFold(n_splits=10)

    # Specifying multiple scoring metrics including ROC-AUC
    scores = cross_validate(model, X, y, groups=groups, cv=cv, scoring=['accuracy', 'precision_macro', 'recall_macro', 'f1_macro', 'roc_auc_ovo_macro', 'roc_auc_ovr_macro'], n_jobs=-1)

    # Displaying the results
    print(f"{model.__class__.__name__} Cross-Validation Accuracy: {np.mean(scores['test_accuracy']):.4f} +/- {np.std(scores['test_accuracy']):.4f}")
    print(f"{model.__class__.__name__} Cross-Validation Precision: {np.mean(scores['test_precision_macro']):.4f} +/- {np.std(scores['test_precision_macro']):.4f}")
    print(f"{model.__class__.__name__} Cross-Validation Recall: {np.mean(scores['test_recall_macro']):.4f} +/- {np.std(scores['test_recall_macro']):.4f}")
    print(f"{model.__class__.__name__} Cross-Validation F1-Score: {np.mean(scores['test_f1_macro']):.4f} +/- {np.std(scores['test_f1_macro']):.4f}")
    print(f"{model.__class__.__name__} Cross-Validation ROC-AUC One-vs-One: {np.mean(scores['test_roc_auc_ovo']):.4f} +/- {np.std(scores['test_roc_auc_ovo']):.4f}")
    print(f"{model.__class__.__name__} Cross-Validation ROC-AUC One-vs-Rest: {np.mean(scores['test_roc_auc_ovr']):.4f} +/- {np.std(scores['test_roc_auc_ovr']):.4f}")

# %%
rf = RandomForestClassifier(random_state=1234, criterion='entropy', max_depth=23, n_estimators=78)
wavelength_df = prepare_wavelength_df(df, 'Absorbance')

evaluate_model(wavelength_df, rf)
# Out:
# ---------------------------------------------------------------------------
# InvalidParameterError                     Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/sklearn/utils/_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#
# File ~/.local/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:360, in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, params, pre_dispatch, return_train_score, return_estimator, return_indices, error_score)
#     359 else:
# --> 360     scorers = _check_multimetric_scoring(estimator, scoring)
#     362 if _routing_enabled():
#     363     # `cross_validate` will create a `_MultiMetricScorer` if `scoring` is a
#     364     # dict at a later stage. We need the same object for the purpose of
#     365     # routing. However, creating it here and passing it around would create
#     366     # a much larger diff since the dict is used in many places.
#
# File ~/.local/lib/python3.10/site-packages/sklearn/metrics/_scorer.py:504, in _check_multimetric_scoring(estimator, scoring)
#     500             raise ValueError(
#     501                 f"{err_msg} Non-string types were found "
#     502                 f"in the given list. Got {scoring!r}"
#     503             )
# --> 504     scorers = {
#     505         scorer: check_scoring(estimator, scoring=scorer) for scorer in scoring
#     506     }
#     507 else:
#
# File ~/.local/lib/python3.10/site-packages/sklearn/metrics/_scorer.py:505, in <dictcomp>(.0)
#     500             raise ValueError(
#     501                 f"{err_msg} Non-string types were found "
#     502                 f"in the given list. Got {scoring!r}"
#     503             )
#     504     scorers = {
# --> 505         scorer: check_scoring(estimator, scoring=scorer) for scorer in scoring
#     506     }
#     507 else:
#
# File ~/.local/lib/python3.10/site-packages/sklearn/utils/_param_validation.py:203, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     201 params = {k: v for k, v in params.arguments.items() if k not in to_ignore}
# --> 203 validate_parameter_constraints(
#     204     parameter_constraints, params, caller_name=func.__qualname__
#     205 )
#     207 try:
#
# File ~/.local/lib/python3.10/site-packages/sklearn/utils/_param_validation.py:95, in validate_parameter_constraints(parameter_constraints, params, caller_name)
#      90     constraints_str = (
#      91         f"{', '.join([str(c) for c in constraints[:-1]])} or"
#      92         f" {constraints[-1]}"
#      93     )
# ---> 95 raise InvalidParameterError(
#      96     f"The {param_name!r} parameter of {caller_name} must be"
#      97     f" {constraints_str}. Got {param_val!r} instead."
#      98 )
#
# InvalidParameterError: The 'scoring' parameter of check_scoring must be a str among {'roc_auc_ovo_weighted', 'recall_micro', 'neg_log_loss', 'roc_auc', 'accuracy', 'jaccard_micro', 'neg_root_mean_squared_log_error', 'jaccard_macro', 'neg_mean_gamma_deviance', 'top_k_accuracy', 'recall_weighted', 'neg_mean_poisson_deviance', 'roc_auc_ovr', 'f1_weighted', 'matthews_corrcoef', 'neg_root_mean_squared_error', 'f1_macro', 'f1', 'fowlkes_mallows_score', 'precision_micro', 'neg_median_absolute_error', 'precision_weighted', 'positive_likelihood_ratio', 'adjusted_mutual_info_score', 'completeness_score', 'homogeneity_score', 'adjusted_rand_score', 'jaccard', 'jaccard_samples', 'neg_mean_squared_log_error', 'precision_samples', 'recall', 'neg_brier_score', 'average_precision', 'neg_negative_likelihood_ratio', 'normalized_mutual_info_score', 'r2', 'neg_mean_absolute_percentage_error', 'mutual_info_score', 'neg_mean_squared_error', 'v_measure_score', 'rand_score', 'precision_macro', 'balanced_accuracy', 'roc_auc_ovr_weighted', 'jaccard_weighted', 'recall_macro', 'f1_micro', 'recall_samples', 'neg_mean_absolute_error', 'precision', 'roc_auc_ovo', 'f1_samples', 'max_error', 'explained_variance'}, a callable or None. Got 'roc_auc_ovo_macro' instead.
#
# The above exception was the direct cause of the following exception:
#
# InvalidParameterError                     Traceback (most recent call last)
# Cell In[27], line 4
#       1 rf = RandomForestClassifier(random_state=1234, criterion='entropy', max_depth=23, n_estimators=78)
#       2 wavelength_df = prepare_wavelength_df(df, 'Absorbance')
# ----> 4 evaluate_model(wavelength_df, rf)
#
# Cell In[26], line 12, in evaluate_model(df, model)
#       9 cv = GroupKFold(n_splits=10)
#      11 # Specifying multiple scoring metrics including ROC-AUC
# ---> 12 scores = cross_validate(model, X, y, groups=groups, cv=cv, scoring=['accuracy', 'precision_macro', 'recall_macro', 'f1_macro', 'roc_auc_ovo_macro', 'roc_auc_ovr_macro'], n_jobs=-1)
#      14 # Displaying the results
#      15 print(f"{model.__class__.__name__} Cross-Validation Accuracy: {np.mean(scores['test_accuracy']):.4f} +/- {np.std(scores['test_accuracy']):.4f}")
#
# File ~/.local/lib/python3.10/site-packages/sklearn/utils/_param_validation.py:224, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
# --> 224     raise InvalidParameterError(msg) from e
#
# InvalidParameterError: The 'scoring' parameter of cross_validate must be a str among {'roc_auc_ovo_weighted', 'recall_micro', 'neg_log_loss', 'roc_auc', 'accuracy', 'jaccard_micro', 'neg_root_mean_squared_log_error', 'jaccard_macro', 'neg_mean_gamma_deviance', 'top_k_accuracy', 'recall_weighted', 'neg_mean_poisson_deviance', 'roc_auc_ovr', 'f1_weighted', 'matthews_corrcoef', 'neg_root_mean_squared_error', 'f1_macro', 'f1', 'fowlkes_mallows_score', 'precision_micro', 'neg_median_absolute_error', 'precision_weighted', 'positive_likelihood_ratio', 'adjusted_mutual_info_score', 'completeness_score', 'homogeneity_score', 'adjusted_rand_score', 'jaccard', 'jaccard_samples', 'neg_mean_squared_log_error', 'precision_samples', 'recall', 'neg_brier_score', 'average_precision', 'neg_negative_likelihood_ratio', 'normalized_mutual_info_score', 'r2', 'neg_mean_absolute_percentage_error', 'mutual_info_score', 'neg_mean_squared_error', 'v_measure_score', 'rand_score', 'precision_macro', 'balanced_accuracy', 'roc_auc_ovr_weighted', 'jaccard_weighted', 'recall_macro', 'f1_micro', 'recall_samples', 'neg_mean_absolute_error', 'precision', 'roc_auc_ovo', 'f1_samples', 'max_error', 'explained_variance'}, a callable or None. Got 'roc_auc_ovo_macro' instead.

# %%
def evaluate_random_forest(df):

    # Set the Surfaces as groups
    groups = df['SurID']
    X = df.drop(['Status', 'SurID'], axis=1)
    y = df['Status']

    # Creating the RandomForest classifier
    rf = RandomForestClassifier(random_state=1234, criterion='entropy', max_depth=23, n_estimators=78)
    
    # Using GroupKFold for classification tasks
    cv = GroupKFold(n_splits=10)

    # Specifying multiple scoring metrics including ROC-AUC
    scores = cross_validate(rf, X, y, groups=groups, cv=cv, scoring=['accuracy', 'precision_macro', 'recall_macro', 'f1_macro', 'roc_auc_ovo_macro', 'roc_auc_ovr_macro'], n_jobs=-1)

    # Displaying the results
    print(f"{rf.__class__.__name__} Cross-Validation Accuracy: {np.mean(scores['test_accuracy']):.4f} +/- {np.std(scores['test_accuracy']):.4f}")
    print(f"{rf.__class__.__name__} Cross-Validation Precision: {np.mean(scores['test_precision_macro']):.4f} +/- {np.std(scores['test_precision_macro']):.4f}")
    print(f"{rf.__class__.__name__} Cross-Validation Recall: {np.mean(scores['test_recall_macro']):.4f} +/- {np.std(scores['test_recall_macro']):.4f}")
    print(f"{rf.__class__.__name__} Cross-Validation F1-Score: {np.mean(scores['test_f1_macro']):.4f} +/- {np.std(scores['test_f1_macro']):.4f}")
    print(f"{rf.__class__.__name__} Cross-Validation ROC-AUC One-vs-One: {np.mean(scores['test_roc_auc_ovo']):.4f} +/- {np.std(scores['test_roc_auc_ovo']):.4f}")
    print(f"{rf.__class__.__name__} Cross-Validation ROC-AUC One-vs-Rest: {np.mean(scores['test_roc_auc_ovr']):.4f} +/- {np.std(scores['test_roc_auc_ovr']):.4f}")

# %%
wavelength_df = prepare_wavelength_df(df, 'Absorbance')
evaluate_random_forest(wavelength_df)
# Out:
# ---------------------------------------------------------------------------
# InvalidParameterError                     Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/sklearn/utils/_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#
# File ~/.local/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:360, in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, params, pre_dispatch, return_train_score, return_estimator, return_indices, error_score)
#     359 else:
# --> 360     scorers = _check_multimetric_scoring(estimator, scoring)
#     362 if _routing_enabled():
#     363     # `cross_validate` will create a `_MultiMetricScorer` if `scoring` is a
#     364     # dict at a later stage. We need the same object for the purpose of
#     365     # routing. However, creating it here and passing it around would create
#     366     # a much larger diff since the dict is used in many places.
#
# File ~/.local/lib/python3.10/site-packages/sklearn/metrics/_scorer.py:504, in _check_multimetric_scoring(estimator, scoring)
#     500             raise ValueError(
#     501                 f"{err_msg} Non-string types were found "
#     502                 f"in the given list. Got {scoring!r}"
#     503             )
# --> 504     scorers = {
#     505         scorer: check_scoring(estimator, scoring=scorer) for scorer in scoring
#     506     }
#     507 else:
#
# File ~/.local/lib/python3.10/site-packages/sklearn/metrics/_scorer.py:505, in <dictcomp>(.0)
#     500             raise ValueError(
#     501                 f"{err_msg} Non-string types were found "
#     502                 f"in the given list. Got {scoring!r}"
#     503             )
#     504     scorers = {
# --> 505         scorer: check_scoring(estimator, scoring=scorer) for scorer in scoring
#     506     }
#     507 else:
#
# File ~/.local/lib/python3.10/site-packages/sklearn/utils/_param_validation.py:203, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     201 params = {k: v for k, v in params.arguments.items() if k not in to_ignore}
# --> 203 validate_parameter_constraints(
#     204     parameter_constraints, params, caller_name=func.__qualname__
#     205 )
#     207 try:
#
# File ~/.local/lib/python3.10/site-packages/sklearn/utils/_param_validation.py:95, in validate_parameter_constraints(parameter_constraints, params, caller_name)
#      90     constraints_str = (
#      91         f"{', '.join([str(c) for c in constraints[:-1]])} or"
#      92         f" {constraints[-1]}"
#      93     )
# ---> 95 raise InvalidParameterError(
#      96     f"The {param_name!r} parameter of {caller_name} must be"
#      97     f" {constraints_str}. Got {param_val!r} instead."
#      98 )
#
# InvalidParameterError: The 'scoring' parameter of check_scoring must be a str among {'recall_weighted', 'neg_brier_score', 'balanced_accuracy', 'neg_mean_absolute_percentage_error', 'neg_median_absolute_error', 'positive_likelihood_ratio', 'fowlkes_mallows_score', 'normalized_mutual_info_score', 'recall', 'roc_auc_ovo_weighted', 'neg_mean_squared_log_error', 'roc_auc_ovr_weighted', 'average_precision', 'roc_auc_ovr', 'recall_samples', 'top_k_accuracy', 'recall_macro', 'recall_micro', 'jaccard_macro', 'roc_auc', 'jaccard_micro', 'precision_samples', 'precision', 'mutual_info_score', 'f1_micro', 'f1_weighted', 'neg_mean_squared_error', 'adjusted_rand_score', 'completeness_score', 'jaccard_samples', 'neg_negative_likelihood_ratio', 'homogeneity_score', 'roc_auc_ovo', 'max_error', 'explained_variance', 'jaccard', 'neg_mean_poisson_deviance', 'precision_micro', 'v_measure_score', 'jaccard_weighted', 'f1_macro', 'r2', 'rand_score', 'precision_macro', 'f1', 'adjusted_mutual_info_score', 'precision_weighted', 'neg_root_mean_squared_log_error', 'accuracy', 'matthews_corrcoef', 'neg_root_mean_squared_error', 'neg_mean_absolute_error', 'neg_log_loss', 'f1_samples', 'neg_mean_gamma_deviance'}, a callable or None. Got 'roc_auc_ovo_macro' instead.
#
# The above exception was the direct cause of the following exception:
#
# InvalidParameterError                     Traceback (most recent call last)
# Cell In[60], line 2
#       1 wavelength_df = prepare_wavelength_df(df, 'Absorbance')
# ----> 2 evaluate_random_forest(wavelength_df)
#
# Cell In[59], line 15, in evaluate_random_forest(df)
#      12 cv = GroupKFold(n_splits=10)
#      14 # Specifying multiple scoring metrics including ROC-AUC
# ---> 15 scores = cross_validate(rf, X, y, groups=groups, cv=cv, scoring=['accuracy', 'precision_macro', 'recall_macro', 'f1_macro', 'roc_auc_ovo_macro', 'roc_auc_ovr_macro'], n_jobs=-1)
#      17 # Displaying the results
#      18 print(f"{rf.__class__.__name__} Cross-Validation Accuracy: {np.mean(scores['test_accuracy']):.4f} +/- {np.std(scores['test_accuracy']):.4f}")
#
# File ~/.local/lib/python3.10/site-packages/sklearn/utils/_param_validation.py:224, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
# --> 224     raise InvalidParameterError(msg) from e
#
# InvalidParameterError: The 'scoring' parameter of cross_validate must be a str among {'recall_weighted', 'neg_brier_score', 'balanced_accuracy', 'neg_mean_absolute_percentage_error', 'neg_median_absolute_error', 'positive_likelihood_ratio', 'fowlkes_mallows_score', 'normalized_mutual_info_score', 'recall', 'roc_auc_ovo_weighted', 'neg_mean_squared_log_error', 'roc_auc_ovr_weighted', 'average_precision', 'roc_auc_ovr', 'recall_samples', 'top_k_accuracy', 'recall_macro', 'recall_micro', 'jaccard_macro', 'roc_auc', 'jaccard_micro', 'precision_samples', 'precision', 'mutual_info_score', 'f1_micro', 'f1_weighted', 'neg_mean_squared_error', 'adjusted_rand_score', 'completeness_score', 'jaccard_samples', 'neg_negative_likelihood_ratio', 'homogeneity_score', 'roc_auc_ovo', 'max_error', 'explained_variance', 'jaccard', 'neg_mean_poisson_deviance', 'precision_micro', 'v_measure_score', 'jaccard_weighted', 'f1_macro', 'r2', 'rand_score', 'precision_macro', 'f1', 'adjusted_mutual_info_score', 'precision_weighted', 'neg_root_mean_squared_log_error', 'accuracy', 'matthews_corrcoef', 'neg_root_mean_squared_error', 'neg_mean_absolute_error', 'neg_log_loss', 'f1_samples', 'neg_mean_gamma_deviance'}, a callable or None. Got 'roc_auc_ovo_macro' instead.

# %% [markdown]
# Try After PageRank Outlier Removal

# %%
df = df[df['PageRank'] > pagerank_cutoff]
wavelength_df = prepare_wavelength_df(df, 'Absorbance')
evaluate_random_forest(wavelength_df)
# Out:
# /home/eddie/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/eddie/.local/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:1011: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/eddie/.local/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 137, in __call__
#     score = scorer._score(
#   File "/home/eddie/.local/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 350, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#   File "/home/eddie/.local/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#   File "/home/eddie/.local/lib/python3.10/site-packages/sklearn/metrics/_ranking.py", line 634, in roc_auc_score
#     return _multiclass_roc_auc_score(
#   File "/home/eddie/.local/lib/python3.10/site-packages/sklearn/metrics/_ranking.py", line 751, in _multiclass_roc_auc_score
#     raise ValueError(
# ValueError: Number of classes in y_true not equal to the number of columns in 'y_score'
#
#   warnings.warn(
# /home/eddie/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/eddie/.local/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:1011: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/eddie/.local/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 137, in __call__
#     score = scorer._score(
#   File "/home/eddie/.local/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 350, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#   File "/home/eddie/.local/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#   File "/home/eddie/.local/lib/python3.10/site-packages/sklearn/metrics/_ranking.py", line 634, in roc_auc_score
#     return _multiclass_roc_auc_score(
#   File "/home/eddie/.local/lib/python3.10/site-packages/sklearn/metrics/_ranking.py", line 751, in _multiclass_roc_auc_score
#     raise ValueError(
# ValueError: Number of classes in y_true not equal to the number of columns in 'y_score'
#
#   warnings.warn(
# RandomForestClassifier Cross-Validation Accuracy: 0.6280 +/- 0.1291
# RandomForestClassifier Cross-Validation Precision: 0.6068 +/- 0.1381
# RandomForestClassifier Cross-Validation Recall: 0.5867 +/- 0.1626
# RandomForestClassifier Cross-Validation F1-Score: 0.5706 +/- 0.1499
# RandomForestClassifier Cross-Validation ROC-AUC One-vs-One: nan +/- nan
# RandomForestClassifier Cross-Validation ROC-AUC One-vs-Rest: nan +/- nan

# %%
def evaluate_random_forest_by_class(df):

    groups = df['SurID']
    X = df.drop(['Status', 'SurID'], axis=1)
    y = df['Status']
    
    # Get unique class names from the 'y' dataset
    class_names = y.unique()

    rf = RandomForestClassifier(random_state=1234, criterion='entropy', max_depth=23, n_estimators=78)
    cv = GroupKFold(n_splits=10)

    accuracies = []
    precisions = [[] for _ in class_names]
    recalls = [[] for _ in class_names]
    f1_scores = [[] for _ in class_names]

    for train_idx, test_idx in cv.split(X, y, groups):
        X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
        y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]
        
        rf.fit(X_train, y_train)
        y_pred = rf.predict(X_test)

        accuracies.append(accuracy_score(y_test, y_pred))
        precision, recall, f1, _ = precision_recall_fscore_support(y_test, y_pred, zero_division=0, labels=class_names)
        for i, (p, r, f) in enumerate(zip(precision, recall, f1)):
            precisions[i].append(p)
            recalls[i].append(r)
            f1_scores[i].append(f)

    print(f"{rf.__class__.__name__} Cross-Validation Accuracy: {np.mean(accuracies):.4f} +/- {np.std(accuracies):.4f}\n")
    for i, class_name in enumerate(class_names):
        print(f"{class_name} Precision: {np.mean(precisions[i]):.4f} +/- {np.std(precisions[i]):.4f}")
        print(f"{class_name} Recall: {np.mean(recalls[i]):.4f} +/- {np.std(recalls[i]):.4f}")
        print(f"{class_name} F1-Score: {np.mean(f1_scores[i]):.4f} +/- {np.std(f1_scores[i]):.4f}\n")

# %%
evaluate_random_forest_by_class(wavelength_df)
# Out:
# RandomForestClassifier Cross-Validation Accuracy: 0.6966 +/- 0.1481
#
# Normal Precision: 0.6489 +/- 0.3186
# Normal Recall: 0.5487 +/- 0.3615
# Normal F1-Score: 0.5421 +/- 0.3374
#
# Hyperglycemia Precision: 0.5810 +/- 0.2302
# Hyperglycemia Recall: 0.6365 +/- 0.2625
# Hyperglycemia F1-Score: 0.5974 +/- 0.2295
#
# Hypoglycemia Precision: 0.7752 +/- 0.2208
# Hypoglycemia Recall: 0.7872 +/- 0.1648
# Hypoglycemia F1-Score: 0.7445 +/- 0.1543

# %%
df.groupby('Status')['SpecID'].nunique()
# Out:
# Status
# Hyperglycemia    502
# Hypoglycemia     653
# Normal           628
# Name: SpecID, dtype: int64

# %% [markdown]
# #### **Finally Try to Predict the Surface by its predicted Spectra**

# %%
df
# Out:
#               SpecID   Seq  WaveNumber  Absorbance     SurID         Status  \
# 4098     201210-1-02   293   400.22778    0.017863  201210-1         Normal
# 4099     201210-1-02   294   400.91116    0.013682  201210-1         Normal
# 4100     201210-1-02   295   401.59454    0.013220  201210-1         Normal
# 4101     201210-1-02   296   402.27789    0.014904  201210-1         Normal
# 4102     201210-1-02   297   402.96127    0.015908  201210-1         Normal
# ...              ...   ...         ...         ...       ...            ...
# 6239200  210526-3-09  2337  1797.03870   -0.016926  210526-3  Hyperglycemia
# 6239201  210526-3-09  2338  1797.72200   -0.014938  210526-3  Hyperglycemia
# 6239202  210526-3-09  2339  1798.40550   -0.014875  210526-3  Hyperglycemia
# 6239203  210526-3-09  2340  1799.08890   -0.013774  210526-3  Hyperglycemia
# 6239204  210526-3-09  2341  1799.77220   -0.016672  210526-3  Hyperglycemia
#
#          PageRank     Baseline
# 4098     0.961147  2041.552352
# 4099     0.961147  2041.568641
# 4100     0.961147  2041.584930
# 4101     0.961147  2041.601219
# 4102     0.961147  2041.617508
# ...           ...          ...
# 6239200  1.201164  1753.639314
# 6239201  1.201164  1753.341720
# 6239202  1.201164  1753.044127
# 6239203  1.201164  1752.746533
# 6239204  1.201164  1752.448939
#
# [3653367 rows x 8 columns]

# %%
def evaluate_and_predict_surface_status(df):
   # Set the Surfaces as groups
    groups = df['SurID']
    X = df.drop(['Status', 'SurID'], axis=1)
    y = df['Status']

    # Creating the RandomForestClassifier
    rf = RandomForestClassifier(random_state=1234, criterion='entropy', max_depth=23, n_estimators=78)
    
    # Using GroupKFold for classification tasks
    cv = GroupKFold(n_splits=10)
    
    # DataFrame to store the actual and predicted status for each spectrum
    predictions_df = pd.DataFrame(columns=['SurID', 'ActualStatus', 'PredictedStatus'])

    # Iterating over each fold
    for train_index, test_index in cv.split(X, y, groups=groups):
        # Splitting the dataset into the current train and test set
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        groups_test = groups.iloc[test_index]
        
        # Fitting the model on the training set
        rf.fit(X_train, y_train)

        # Predicting the status for the test set
        y_pred = rf.predict(X_test)

        # Appending the SurID, actual, and predicted status to the predictions DataFrame
        fold_predictions = pd.DataFrame({
            'SurID': groups_test.values,
            'ActualStatus': y_test.values,
            'PredictedStatus': y_pred
        })
        predictions_df = pd.concat([predictions_df, fold_predictions], ignore_index=True)

    # Return the most common prediction of each spectra within the surface
    return predictions_df.groupby('SurID').agg(lambda x: x.mode()[0]).reset_index()

# %%
surface_predictions = evaluate_and_predict_surface_status(wavelength_df)
surface_predictions
# Out:
#        SurID   ActualStatus PredictedStatus
# 0   201210-1         Normal          Normal
# 1   201210-2         Normal    Hypoglycemia
# 2   210114-1         Normal          Normal
# 3   210114-2         Normal          Normal
# 4   210120-1  Hyperglycemia          Normal
# ..       ...            ...             ...
# 58  210519-3  Hyperglycemia   Hyperglycemia
# 59  210524-1   Hypoglycemia   Hyperglycemia
# 60  210526-1  Hyperglycemia   Hyperglycemia
# 61  210526-2  Hyperglycemia          Normal
# 62  210526-3  Hyperglycemia    Hypoglycemia
#
# [63 rows x 3 columns]

# %%
print(classification_report(surface_predictions['ActualStatus'], surface_predictions['PredictedStatus']))
# Out:
#                precision    recall  f1-score   support
#
# Hyperglycemia       0.70      0.74      0.72        19
#  Hypoglycemia       0.72      0.82      0.77        22
#        Normal       0.78      0.64      0.70        22
#
#      accuracy                           0.73        63
#     macro avg       0.73      0.73      0.73        63
#  weighted avg       0.73      0.73      0.73        63
