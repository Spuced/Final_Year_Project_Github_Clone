# %% [markdown]
# ### **This Notebook Performs a Parameters Search on Every Possible Cleaning and Model Parameter.**

# %% [markdown]
# Lets test different spectral cleaning parameters by building a model pipeline.

# %% [markdown]
# Import Libraries

# %%
import pandas as pd
import numpy as np
from scipy.signal import savgol_filter
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.svm import SVC
from sklearn.model_selection import cross_validate, GroupKFold, cross_val_score, KFold
from Spectra_Preparation_Functions import *
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.pipeline import Pipeline
import optuna

# %% [markdown]
# Read the spectral data

# %%
#df = pd.read_csv("../../data/exosomes.raw_spectrum_1.csv")
# df = pd.read_csv("../../data/raw_df_outliers_removed.csv")
df = pd.read_csv("../../data/exosomes.raw_spectrum_400-1800.csv")

# %%
df
# Out:
#               SpecID   Seq  WaveNumber  Absorbance     SurID         Status
# 0        201210-1-00   293   400.22778   1765.6628  201210-1         Normal
# 1        201210-1-00   294   400.91116   1774.7809  201210-1         Normal
# 2        201210-1-00   295   401.59454   1769.0302  201210-1         Normal
# 3        201210-1-00   296   402.27789   1756.4220  201210-1         Normal
# 4        201210-1-00   297   402.96127   1758.8690  201210-1         Normal
# ...              ...   ...         ...         ...       ...            ...
# 6239200  210526-3-09  2337  1797.03870   1617.3926  210526-3  Hyperglycemia
# 6239201  210526-3-09  2338  1797.72200   1633.0911  210526-3  Hyperglycemia
# 6239202  210526-3-09  2339  1798.40550   1633.3076  210526-3  Hyperglycemia
# 6239203  210526-3-09  2340  1799.08890   1641.8665  210526-3  Hyperglycemia
# 6239204  210526-3-09  2341  1799.77220   1618.2405  210526-3  Hyperglycemia
#
# [6239205 rows x 6 columns]

# %%
wavelength_df = prepare_wavelength_df(df, 'Absorbance')
wavelength_df.head()
# Out:
#              400.22778  400.91116  401.59454  402.27789  402.96127  403.64465  \
# SpecID
# 201210-1-00  1765.6628  1774.7809  1769.0302  1756.4220  1758.8690  1763.2300
# 201210-1-01  1966.9930  1962.4237  1954.5616  1954.3228  1963.0917  1975.0807
# 201210-1-02  2182.6694  2149.6565  2146.0227  2159.3459  2167.2910  2160.9861
# 201210-1-03  2445.0837  2430.4973  2422.7927  2434.3433  2454.9700  2462.8245
# 201210-1-04  2250.4536  2248.6235  2245.0984  2242.7173  2235.2803  2228.9585
#
#              404.32803  405.01138  405.69476  406.37814  ...  1794.9886  \
# SpecID                                                   ...
# 201210-1-00  1745.2285  1773.3534  1774.7166  1753.3281  ...  1210.4993
# 201210-1-01  1979.3162  1963.4561  1968.4587  1964.0000  ...  1382.6973
# 201210-1-02  2145.6575  2134.2004  2142.8303  2138.6309  ...  1976.2070
# 201210-1-03  2454.7007  2467.7329  2449.5161  2421.3474  ...  1992.3817
# 201210-1-04  2236.0095  2229.6091  2225.9231  2211.0359  ...  2009.0385
#
#               1795.672  1796.3553  1797.0387   1797.722  1798.4055  1799.0889  \
# SpecID
# 201210-1-00  1213.9619  1225.2153  1210.0010  1210.6858  1194.4679  1195.1451
# 201210-1-01  1363.7004  1360.6210  1354.0477  1353.0381  1353.9978  1361.2426
# 201210-1-02  1989.0183  1996.2838  1979.3507  1976.2002  1994.9839  1974.2030
# 201210-1-03  2022.6331  2001.8311  2010.0946  2006.4933  2017.2891  2038.1699
# 201210-1-04  1953.3303  1963.5698  1964.5299  1969.5634  1986.6266  1970.1484
#
#              1799.7722     SurID  Status
# SpecID
# 201210-1-00  1189.8683  201210-1  Normal
# 201210-1-01  1370.2874  201210-1  Normal
# 201210-1-02  1971.1880  201210-1  Normal
# 201210-1-03  2000.6475  201210-1  Normal
# 201210-1-04  2007.0848  201210-1  Normal
#
# [5 rows x 2051 columns]

# %% [markdown]
# >#### **Use Optuna to Find the Best Cleaning Parameter**

# %%
df
# Out:
#               SpecID   Seq  WaveNumber  Absorbance     SurID         Status
# 0        201210-1-00   293   400.22778   1765.6628  201210-1         Normal
# 1        201210-1-00   294   400.91116   1774.7809  201210-1         Normal
# 2        201210-1-00   295   401.59454   1769.0302  201210-1         Normal
# 3        201210-1-00   296   402.27789   1756.4220  201210-1         Normal
# 4        201210-1-00   297   402.96127   1758.8690  201210-1         Normal
# ...              ...   ...         ...         ...       ...            ...
# 6239200  210526-3-09  2337  1797.03870   1617.3926  210526-3  Hyperglycemia
# 6239201  210526-3-09  2338  1797.72200   1633.0911  210526-3  Hyperglycemia
# 6239202  210526-3-09  2339  1798.40550   1633.3076  210526-3  Hyperglycemia
# 6239203  210526-3-09  2340  1799.08890   1641.8665  210526-3  Hyperglycemia
# 6239204  210526-3-09  2341  1799.77220   1618.2405  210526-3  Hyperglycemia
#
# [6239205 rows x 6 columns]

# %%
def objective(trial):

    # Decide which cleaning steps to implement
    despike = trial.suggest_categorical('despike', [True, False])
    baseline_correct = trial.suggest_categorical('baseline_correct', [True, False])
    smoothing = trial.suggest_categorical('smoothing', [True, False])
    scaling = trial.suggest_categorical('scaling', [True, False])

    df_copy = df.copy()

    # Apply preprocessing based on suggested parameters
    if despike:
        despike_ma = trial.suggest_int('despike_ma', 5, 100)
        despike_threshold = trial.suggest_float('despike_threshold', 3, 10, step=0.25)
        df_copy['Absorbance'] = df_copy.groupby('SpecID')['Absorbance'].transform(lambda x: despike_group(x, ma=despike_ma, threshold = despike_threshold))

    if baseline_correct:

        lam = trial.suggest_categorical('asls_lam', [10**2, 10**3, 10**4, 10**5, 10**6, 10**7, 10**8, 10**9, 10**10, 10**11])
        p = trial.suggest_float('asls_p', 0.001, 0.1, step=0.001)
        df_copy['Baseline'] = df_copy.groupby('SpecID')['Absorbance'].transform(lambda x: asls_baseline_correction(x, lam=lam, p=p))
        df_copy['Absorbance'] = df_copy['Absorbance'] - df_copy['Baseline']

    if smoothing:
        window_size = trial.suggest_int('window_size', 6, 251)
        poly_order = trial.suggest_int('smoothing_poly_order', 1, 5)
        df_copy['Absorbance'] = df_copy.groupby('SpecID')['Absorbance'].transform(lambda x: savgol_filter(x, window_size, poly_order, deriv=0))

    if scaling:
        scaling_type = trial.suggest_categorical('scaling_type', ['normal', 'vector', 'svn'])
        if scaling_type == 'normal':
            df_copy['Absorbance'] = df_copy.groupby('SpecID')['Absorbance'].transform(lambda x: normalise(x))
        elif scaling_type == 'vector':
            df_copy['Absorbance'] = df_copy.groupby('SpecID')['Absorbance'].transform(lambda x: vector_normalise(x))
        else:
            df_copy['Absorbance'] = df_copy.groupby('SpecID')['Absorbance'].transform(lambda x: svn_normalise(x))

    # Prepare data for ML
    wavelength_df = prepare_wavelength_df(df_copy, 'Absorbance')
    X = wavelength_df.drop(['Status', 'SurID'], axis=1)
    y = wavelength_df['Status']
    groups = wavelength_df['SurID']

    # Suggest classifier type
    classifier_name = trial.suggest_categorical("classifier", ["ExtraTrees", "RandomForest", "SVC"])

    if classifier_name == "ExtraTrees":
        classifier = ExtraTreesClassifier()

    elif classifier_name == "RandomForest":
        classifier = RandomForestClassifier()
        
    else: # SVC
        classifier = SVC()
        
    cv = KFold(n_splits=10, shuffle=True, random_state=1234)

    # Perform cross-validation
    scores = cross_validate(classifier, X, y, groups=groups, cv=cv, scoring='accuracy', n_jobs=-1)

    # Return the average accuracy across all folds
    return np.mean(scores['test_score'])


# sampler = TPESampler(seed=10)  # Make the sampler behave in a deterministic way.
# study = optuna.create_study(direction='maximise', sampler=sampler)

study = optuna.create_study(direction="maximize")
# study.optimize(objective, n_trials=100, n_jobs=-1)
study.optimize(objective, n_trials=100, n_jobs=-1)

print(study.best_trial)
# Out:
# [I 2024-04-14 15:12:15,522] A new study created in memory with name: no-name-706a35b5-6e3e-4475-b38c-ca7f5e348065
# [I 2024-04-14 15:14:07,945] Trial 10 finished with value: 0.5171111111111111 and parameters: {'despike': False, 'baseline_correct': False, 'smoothing': True, 'scaling': False, 'window_size': 61, 'smoothing_poly_order': 1, 'classifier': 'RandomForest'}. Best is trial 10 with value: 0.5171111111111111.
# [I 2024-04-14 15:14:16,788] Trial 3 finished with value: 0.5240634920634921 and parameters: {'despike': False, 'baseline_correct': False, 'smoothing': True, 'scaling': False, 'window_size': 27, 'smoothing_poly_order': 2, 'classifier': 'RandomForest'}. Best is trial 3 with value: 0.5240634920634921.
# [I 2024-04-14 15:14:29,804] Trial 2 finished with value: 0.5275714285714286 and parameters: {'despike': True, 'baseline_correct': False, 'smoothing': False, 'scaling': False, 'despike_ma': 92, 'despike_threshold': 9.25, 'classifier': 'RandomForest'}. Best is trial 2 with value: 0.5275714285714286.
# [I 2024-04-14 15:14:35,259] Trial 8 finished with value: 0.5108412698412699 and parameters: {'despike': False, 'baseline_correct': False, 'smoothing': True, 'scaling': True, 'window_size': 75, 'smoothing_poly_order': 1, 'scaling_type': 'vector', 'classifier': 'ExtraTrees'}. Best is trial 2 with value: 0.5275714285714286.
# [I 2024-04-14 15:14:42,290] Trial 0 finished with value: 0.5323650793650794 and parameters: {'despike': True, 'baseline_correct': False, 'smoothing': False, 'scaling': False, 'despike_ma': 60, 'despike_threshold': 4.0, 'classifier': 'ExtraTrees'}. Best is trial 0 with value: 0.5323650793650794.
# [I 2024-04-14 15:15:21,396] Trial 1 finished with value: 0.5323968253968254 and parameters: {'despike': True, 'baseline_correct': False, 'smoothing': True, 'scaling': False, 'despike_ma': 51, 'despike_threshold': 8.75, 'window_size': 34, 'smoothing_poly_order': 3, 'classifier': 'ExtraTrees'}. Best is trial 1 with value: 0.5323968253968254.
# [I 2024-04-14 15:15:24,915] Trial 4 finished with value: 0.5241111111111111 and parameters: {'despike': True, 'baseline_correct': False, 'smoothing': True, 'scaling': False, 'despike_ma': 9, 'despike_threshold': 10.0, 'window_size': 127, 'smoothing_poly_order': 1, 'classifier': 'ExtraTrees'}. Best is trial 1 with value: 0.5323968253968254.
# [I 2024-04-14 15:15:44,137] Trial 12 finished with value: 0.5316349206349206 and parameters: {'despike': True, 'baseline_correct': False, 'smoothing': False, 'scaling': False, 'despike_ma': 43, 'despike_threshold': 5.75, 'classifier': 'RandomForest'}. Best is trial 1 with value: 0.5323968253968254.
# [I 2024-04-14 15:15:46,537] Trial 11 finished with value: 0.5330952380952381 and parameters: {'despike': True, 'baseline_correct': False, 'smoothing': True, 'scaling': True, 'despike_ma': 46, 'despike_threshold': 5.75, 'window_size': 80, 'smoothing_poly_order': 3, 'scaling_type': 'vector', 'classifier': 'ExtraTrees'}. Best is trial 11 with value: 0.5330952380952381.
# [I 2024-04-14 15:16:30,126] Trial 6 finished with value: 0.4593174603174603 and parameters: {'despike': True, 'baseline_correct': False, 'smoothing': True, 'scaling': True, 'despike_ma': 94, 'despike_threshold': 4.5, 'window_size': 171, 'smoothing_poly_order': 1, 'scaling_type': 'normal', 'classifier': 'SVC'}. Best is trial 11 with value: 0.5330952380952381.
# [I 2024-04-14 15:16:47,228] Trial 17 finished with value: 0.515888888888889 and parameters: {'despike': False, 'baseline_correct': False, 'smoothing': True, 'scaling': False, 'window_size': 191, 'smoothing_poly_order': 1, 'classifier': 'RandomForest'}. Best is trial 11 with value: 0.5330952380952381.
# [I 2024-04-14 15:17:46,678] Trial 13 finished with value: 0.4712063492063492 and parameters: {'despike': True, 'baseline_correct': False, 'smoothing': True, 'scaling': False, 'despike_ma': 83, 'despike_threshold': 7.25, 'window_size': 22, 'smoothing_poly_order': 1, 'classifier': 'SVC'}. Best is trial 11 with value: 0.5330952380952381.
# [I 2024-04-14 15:18:11,684] Trial 18 finished with value: 0.4705396825396826 and parameters: {'despike': False, 'baseline_correct': False, 'smoothing': True, 'scaling': False, 'window_size': 171, 'smoothing_poly_order': 4, 'classifier': 'SVC'}. Best is trial 11 with value: 0.5330952380952381.
# [I 2024-04-14 15:18:13,094] Trial 19 finished with value: 0.5402063492063492 and parameters: {'despike': False, 'baseline_correct': False, 'smoothing': True, 'scaling': True, 'window_size': 50, 'smoothing_poly_order': 4, 'scaling_type': 'vector', 'classifier': 'ExtraTrees'}. Best is trial 19 with value: 0.5402063492063492.
# [I 2024-04-14 15:19:16,683] Trial 7 finished with value: 0.45396825396825397 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': False, 'scaling': False, 'baseline_correction_type': 'airpls', 'airpls_lam': 100000000000, 'classifier': 'SVC'}. Best is trial 19 with value: 0.5402063492063492.
# [I 2024-04-14 15:20:26,758] Trial 20 finished with value: 0.5787142857142857 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': False, 'scaling': False, 'baseline_correction_type': 'asls', 'asls_lam': 10000000, 'asls_p': 0.07, 'classifier': 'RandomForest'}. Best is trial 20 with value: 0.5787142857142857.
# [I 2024-04-14 15:20:35,508] Trial 14 finished with value: 0.5868412698412699 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': False, 'scaling': True, 'baseline_correction_type': 'airpls', 'airpls_lam': 10000000000, 'scaling_type': 'vector', 'classifier': 'ExtraTrees'}. Best is trial 14 with value: 0.5868412698412699.
# [I 2024-04-14 15:20:38,252] Trial 16 finished with value: 0.5827142857142857 and parameters: {'despike': True, 'baseline_correct': True, 'smoothing': True, 'scaling': True, 'despike_ma': 86, 'despike_threshold': 9.5, 'baseline_correction_type': 'poly', 'polyfit_poly_order': 5, 'window_size': 19, 'smoothing_poly_order': 2, 'scaling_type': 'vector', 'classifier': 'RandomForest'}. Best is trial 14 with value: 0.5868412698412699.
# [I 2024-04-14 15:21:26,856] Trial 5 finished with value: 0.5134444444444445 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': False, 'scaling': True, 'baseline_correction_type': 'iasls', 'iasls_lam': 10000, 'iasls_p': 0.044000000000000004, 'iasls_lam_1': 0.001, 'scaling_type': 'normal', 'classifier': 'SVC'}. Best is trial 14 with value: 0.5868412698412699.
# [I 2024-04-14 15:22:40,910] Trial 21 finished with value: 0.5731587301587301 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': False, 'scaling': True, 'baseline_correction_type': 'airpls', 'airpls_lam': 10000000000, 'scaling_type': 'svn', 'classifier': 'SVC'}. Best is trial 14 with value: 0.5868412698412699.
# [I 2024-04-14 15:23:03,509] Trial 25 finished with value: 0.5485555555555555 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': False, 'scaling': True, 'baseline_correction_type': 'airpls', 'airpls_lam': 100000000, 'scaling_type': 'vector', 'classifier': 'ExtraTrees'}. Best is trial 14 with value: 0.5868412698412699.
# [I 2024-04-14 15:24:04,128] Trial 29 finished with value: 0.5306825396825396 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': False, 'scaling': True, 'baseline_correction_type': 'poly', 'polyfit_poly_order': 5, 'scaling_type': 'svn', 'classifier': 'ExtraTrees'}. Best is trial 14 with value: 0.5868412698412699.
# [I 2024-04-14 15:24:29,372] Trial 27 finished with value: 0.5347460317460319 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': False, 'scaling': True, 'baseline_correction_type': 'asls', 'asls_lam': 10000000, 'asls_p': 0.069, 'scaling_type': 'svn', 'classifier': 'ExtraTrees'}. Best is trial 14 with value: 0.5868412698412699.
# [I 2024-04-14 15:24:52,516] Trial 28 finished with value: 0.5426190476190477 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': False, 'scaling': True, 'baseline_correction_type': 'asls', 'asls_lam': 10000000, 'asls_p': 0.076, 'scaling_type': 'svn', 'classifier': 'RandomForest'}. Best is trial 14 with value: 0.5868412698412699.
# [I 2024-04-14 15:25:05,328] Trial 30 finished with value: 0.5345079365079364 and parameters: {'despike': True, 'baseline_correct': True, 'smoothing': False, 'scaling': True, 'despike_ma': 74, 'despike_threshold': 7.75, 'baseline_correction_type': 'poly', 'polyfit_poly_order': 5, 'scaling_type': 'svn', 'classifier': 'ExtraTrees'}. Best is trial 14 with value: 0.5868412698412699.
# [I 2024-04-14 15:25:26,372] Trial 23 finished with value: 0.5900952380952381 and parameters: {'despike': True, 'baseline_correct': True, 'smoothing': True, 'scaling': True, 'despike_ma': 40, 'despike_threshold': 7.5, 'baseline_correction_type': 'asls', 'asls_lam': 100000000, 'asls_p': 0.001, 'window_size': 99, 'smoothing_poly_order': 4, 'scaling_type': 'vector', 'classifier': 'ExtraTrees'}. Best is trial 23 with value: 0.5900952380952381.
# [I 2024-04-14 15:25:34,350] Trial 31 finished with value: 0.530984126984127 and parameters: {'despike': True, 'baseline_correct': True, 'smoothing': False, 'scaling': True, 'despike_ma': 71, 'despike_threshold': 7.5, 'baseline_correction_type': 'poly', 'polyfit_poly_order': 5, 'scaling_type': 'vector', 'classifier': 'ExtraTrees'}. Best is trial 23 with value: 0.5900952380952381.
# [I 2024-04-14 15:26:10,734] Trial 32 finished with value: 0.5372380952380953 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': False, 'scaling': True, 'baseline_correction_type': 'asls', 'asls_lam': 10000000, 'asls_p': 0.07300000000000001, 'scaling_type': 'vector', 'classifier': 'RandomForest'}. Best is trial 23 with value: 0.5900952380952381.
# [I 2024-04-14 15:26:28,790] Trial 24 finished with value: 0.42530158730158735 and parameters: {'despike': True, 'baseline_correct': True, 'smoothing': True, 'scaling': True, 'despike_ma': 42, 'despike_threshold': 7.5, 'baseline_correction_type': 'iasls', 'iasls_lam': 100, 'iasls_p': 0.09, 'iasls_lam_1': 1e-05, 'window_size': 91, 'smoothing_poly_order': 3, 'scaling_type': 'svn', 'classifier': 'ExtraTrees'}. Best is trial 23 with value: 0.5900952380952381.
# [I 2024-04-14 15:27:16,524] Trial 33 finished with value: 0.5411904761904762 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': False, 'scaling': True, 'baseline_correction_type': 'asls', 'asls_lam': 10000000, 'asls_p': 0.07100000000000001, 'scaling_type': 'vector', 'classifier': 'RandomForest'}. Best is trial 23 with value: 0.5900952380952381.
# [I 2024-04-14 15:27:31,135] Trial 35 finished with value: 0.5376507936507936 and parameters: {'despike': True, 'baseline_correct': True, 'smoothing': False, 'scaling': True, 'despike_ma': 73, 'despike_threshold': 7.75, 'baseline_correction_type': 'poly', 'polyfit_poly_order': 5, 'scaling_type': 'vector', 'classifier': 'RandomForest'}. Best is trial 23 with value: 0.5900952380952381.
# [I 2024-04-14 15:28:23,005] Trial 34 finished with value: 0.5884285714285713 and parameters: {'despike': True, 'baseline_correct': True, 'smoothing': False, 'scaling': True, 'despike_ma': 73, 'despike_threshold': 7.5, 'baseline_correction_type': 'asls', 'asls_lam': 100000000000, 'asls_p': 0.08600000000000001, 'scaling_type': 'vector', 'classifier': 'RandomForest'}. Best is trial 23 with value: 0.5900952380952381.
# [I 2024-04-14 15:29:10,686] Trial 15 finished with value: 0.5245396825396826 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': False, 'scaling': False, 'baseline_correction_type': 'psalsa', 'psalsa_lam': 10000, 'psalsa_p': 0.23574277677630795, 'classifier': 'ExtraTrees'}. Best is trial 23 with value: 0.5900952380952381.
# [I 2024-04-14 15:30:52,096] Trial 22 finished with value: 0.5833492063492064 and parameters: {'despike': True, 'baseline_correct': True, 'smoothing': True, 'scaling': True, 'despike_ma': 49, 'despike_threshold': 7.5, 'baseline_correction_type': 'psalsa', 'psalsa_lam': 100000000000, 'psalsa_p': 0.45122567605013497, 'window_size': 13, 'smoothing_poly_order': 4, 'scaling_type': 'vector', 'classifier': 'ExtraTrees'}. Best is trial 23 with value: 0.5900952380952381.
# [I 2024-04-14 15:31:24,760] Trial 26 finished with value: 0.5388095238095238 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': True, 'scaling': True, 'baseline_correction_type': 'psalsa', 'psalsa_lam': 1000000, 'psalsa_p': 0.4360916893668316, 'window_size': 108, 'smoothing_poly_order': 4, 'scaling_type': 'vector', 'classifier': 'ExtraTrees'}. Best is trial 23 with value: 0.5900952380952381.
# [I 2024-04-14 15:31:35,893] Trial 9 finished with value: 0.5292222222222223 and parameters: {'despike': True, 'baseline_correct': True, 'smoothing': False, 'scaling': False, 'despike_ma': 57, 'despike_threshold': 3.25, 'baseline_correction_type': 'psalsa', 'psalsa_lam': 100000000000, 'psalsa_p': 0.831734137616083, 'classifier': 'ExtraTrees'}. Best is trial 23 with value: 0.5900952380952381.
# [I 2024-04-14 15:32:33,093] Trial 36 finished with value: 0.5720000000000001 and parameters: {'despike': False, 'baseline_correct': True, 'smoothing': False, 'scaling': True, 'baseline_correction_type': 'psalsa', 'psalsa_lam': 100000000, 'psalsa_p': 0.03435108310126467, 'scaling_type': 'vector', 'classifier': 'RandomForest'}. Best is trial 23 with value: 0.5900952380952381.
# [I 2024-04-14 15:34:01,071] Trial 42 finished with value: 0.4707301587301587 and parameters: {'despike': True, 'baseline_correct': True, 'smoothing': True, 'scaling': True, 'despike_ma': 25, 'despike_threshold': 8.75, 'baseline_correction_type': 'psalsa', 'psalsa_lam': 100, 'psalsa_p': 0.24380829783428593, 'window_size': 121, 'smoothing_poly_order': 2, 'scaling_type': 'vector', 'classifier': 'RandomForest'}. Best is trial 23 with value: 0.5900952380952381.
# [I 2024-04-14 15:34:03,910] Trial 37 finished with value: 0.5176190476190476 and parameters: {'despike': True, 'baseline_correct': True, 'smoothing': True, 'scaling': True, 'despike_ma': 21, 'despike_threshold': 8.25, 'baseline_correction_type': 'psalsa', 'psalsa_lam': 100000, 'psalsa_p': 0.2638882437301185, 'window_size': 117, 'smoothing_poly_order': 2, 'scaling_type': 'vector', 'classifier': 'ExtraTrees'}. Best is trial 23 with value: 0.5900952380952381.
# [I 2024-04-14 15:34:06,346] Trial 39 finished with value: 0.5650158730158731 and parameters: {'despike': True, 'baseline_correct': True, 'smoothing': True, 'scaling': True, 'despike_ma': 27, 'despike_threshold': 8.5, 'baseline_correction_type': 'psalsa', 'psalsa_lam': 10000000, 'psalsa_p': 0.2670057774834504, 'window_size': 118, 'smoothing_poly_order': 2, 'scaling_type': 'vector', 'classifier': 'ExtraTrees'}. Best is trial 23 with value: 0.5900952380952381.
# [I 2024-04-14 15:34:09,159] Trial 41 finished with value: 0.4563174603174603 and parameters: {'despike': True, 'baseline_correct': True, 'smoothing': True, 'scaling': True, 'despike_ma': 24, 'despike_threshold': 8.75, 'baseline_correction_type': 'psalsa', 'psalsa_lam': 1000, 'psalsa_p': 0.6274646106357494, 'window_size': 124, 'smoothing_poly_order': 2, 'scaling_type': 'vector', 'classifier': 'ExtraTrees'}. Best is trial 23 with value: 0.5900952380952381.
# [I 2024-04-14 15:35:38,569] Trial 48 finished with value: 0.5520476190476191 and parameters: {'despike': True, 'baseline_correct': True, 'smoothing': True, 'scaling': True, 'despike_ma': 26, 'despike_threshold': 6.75, 'baseline_correction_type': 'airpls', 'airpls_lam': 10000000, 'window_size': 131, 'smoothing_poly_order': 4, 'scaling_type': 'vector', 'classifier': 'ExtraTrees'}. Best is trial 23 with value: 0.5900952380952381.
# [I 2024-04-14 15:35:52,886] Trial 43 finished with value: 0.46982539682539687 and parameters: {'despike': True, 'baseline_correct': True, 'smoothing': True, 'scaling': True, 'despike_ma': 27, 'despike_threshold': 8.75, 'baseline_correction_type': 'psalsa', 'psalsa_lam': 1000, 'psalsa_p': 0.32969967528561517, 'window_size': 129, 'smoothing_poly_order': 2, 'scaling_type': 'vector', 'classifier': 'RandomForest'}. Best is trial 23 with value: 0.5900952380952381.
# [I 2024-04-14 15:36:55,209] Trial 38 finished with value: 0.5449365079365079 and parameters: {'despike': True, 'baseline_correct': True, 'smoothing': True, 'scaling': True, 'despike_ma': 25, 'despike_threshold': 8.25, 'baseline_correction_type': 'psalsa', 'psalsa_lam': 100000000, 'psalsa_p': 0.4699609163085808, 'window_size': 132, 'smoothing_poly_order': 2, 'scaling_type': 'vector', 'classifier': 'RandomForest'}. Best is trial 23 with value: 0.5900952380952381.
# [I 2024-04-14 15:37:34,743] Trial 52 finished with value: 0.48093650793650794 and parameters: {'despike': True, 'baseline_correct': True, 'smoothing': True, 'scaling': True, 'despike_ma': 36, 'despike_threshold': 6.5, 'baseline_correction_type': 'airpls', 'airpls_lam': 10000, 'window_size': 10, 'smoothing_poly_order': 4, 'scaling_type': 'vector', 'classifier': 'RandomForest'}. Best is trial 23 with value: 0.5900952380952381.
# [I 2024-04-14 15:37:39,117] Trial 51 finished with value: 0.5212857142857144 and parameters: {'despike': True, 'baseline_correct': True, 'smoothing': True, 'scaling': True, 'despike_ma': 34, 'despike_threshold': 6.75, 'baseline_correction_type': 'airpls', 'airpls_lam': 10000000, 'window_size': 6, 'smoothing_poly_order': 4, 'scaling_type': 'normal', 'classifier': 'ExtraTrees'}. Best is trial 23 with value: 0.5900952380952381.
# [I 2024-04-14 15:38:17,713] Trial 49 finished with value: 0.5418095238095237 and parameters: {'despike': True, 'baseline_correct': True, 'smoothing': True, 'scaling': True, 'despike_ma': 33, 'despike_threshold': 6.5, 'baseline_correction_type': 'airpls', 'airpls_lam': 1000000, 'window_size': 148, 'smoothing_poly_order': 4, 'scaling_type': 'normal', 'classifier': 'ExtraTrees'}. Best is trial 23 with value: 0.5900952380952381.
# [I 2024-04-14 15:38:19,998] Trial 40 finished with value: 0.560968253968254 and parameters: {'despike': True, 'baseline_correct': True, 'smoothing': True, 'scaling': True, 'despike_ma': 25, 'despike_threshold': 8.75, 'baseline_correction_type': 'psalsa', 'psalsa_lam': 100000000, 'psalsa_p': 0.5990491510688338, 'window_size': 128, 'smoothing_poly_order': 2, 'scaling_type': 'vector', 'classifier': 'ExtraTrees'}. Best is trial 23 with value: 0.5900952380952381.
# [I 2024-04-14 15:38:52,979] Trial 50 finished with value: 0.5512698412698412 and parameters: {'despike': True, 'baseline_correct': True, 'smoothing': True, 'scaling': True, 'despike_ma': 28, 'despike_threshold': 6.5, 'baseline_correction_type': 'airpls', 'airpls_lam': 1000000000, 'window_size': 155, 'smoothing_poly_order': 4, 'scaling_type': 'normal', 'classifier': 'ExtraTrees'}. Best is trial 23 with value: 0.5900952380952381.
# [I 2024-04-14 15:40:24,347] Trial 53 finished with value: 0.5542698412698412 and parameters: {'despike': True, 'baseline_correct': True, 'smoothing': True, 'scaling': True, 'despike_ma': 83, 'despike_threshold': 6.25, 'baseline_correction_type': 'asls', 'asls_lam': 100000000000, 'asls_p': 0.002, 'window_size': 6, 'smoothing_poly_order': 3, 'scaling_type': 'normal', 'classifier': 'RandomForest'}. Best is trial 23 with value: 0.5900952380952381.
# [I 2024-04-14 15:40:53,803] Trial 54 finished with value: 0.5581111111111111 and parameters: {'despike': True, 'baseline_correct': True, 'smoothing': True, 'scaling': True, 'despike_ma': 63, 'despike_threshold': 6.25, 'baseline_correction_type': 'asls', 'asls_lam': 100000000000, 'asls_p': 0.002, 'window_size': 17, 'smoothing_poly_order': 3, 'scaling_type': 'normal', 'classifier': 'RandomForest'}. Best is trial 23 with value: 0.5900952380952381.
# [I 2024-04-14 15:42:27,648] Trial 55 finished with value: 0.5552698412698412 and parameters: {'despike': True, 'baseline_correct': True, 'smoothing': True, 'scaling': True, 'despike_ma': 63, 'despike_threshold': 6.5, 'baseline_correction_type': 'asls', 'asls_lam': 100000000000, 'asls_p': 0.001, 'window_size': 6, 'smoothing_poly_order': 3, 'scaling_type': 'normal', 'classifier': 'ExtraTrees'}. Best is trial 23 with value: 0.5900952380952381.

# %%
results_df = study.trials_dataframe(attrs=("number", "value", "params", "state"))
results_df.to_csv("../../data/studies/cleaning_only_kfold.csv")

# %%
import joblib

joblib.dump(study, "../../data/studies/cleaning_only_kfold.pkl")

# loaded_study = joblib.load("../../data/studies/cleaning_study.pkl")
# print("Best trial until now:")
# print(" Value: ", loaded_study.best_trial.value)
# print(" Params: ")
# for key, value in loaded_study.best_trial.params.items():
#     print(f"    {key}: {value}")

# %%
print(study.best_trial)

# %%
from optuna.visualization import plot_optimization_history, plot_slice

plot_optimization_history(study)

# %%
plot_slice(study)

# %%
optuna.visualization.plot_contour(study)

# %%
optuna.visualization.plot_param_importances(study)

# %% [markdown]
# Continue the study.

# %%
study.optimize(objective, n_trials=400, n_jobs=-1)

print(study.best_trial)

# %%
results_df = study.trials_dataframe(attrs=("number", "value", "params", "state"))
results_df.to_csv("../../data/studies/cleaning_only_kfold.csv")

# %%
import joblib

joblib.dump(study, "../../data/studies/cleaning_only_kfold.pkl")

# loaded_study = joblib.load("../../data/studies/cleaning_study.pkl")
# print("Best trial until now:")
# print(" Value: ", loaded_study.best_trial.value)
# print(" Params: ")
# for key, value in loaded_study.best_trial.params.items():
#     print(f"    {key}: {value}")
