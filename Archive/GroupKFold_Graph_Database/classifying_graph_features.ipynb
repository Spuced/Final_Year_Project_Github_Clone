# %% [markdown]
# #### **Classifying the Graph Metrics With SVC**

# %%
import pandas as pd
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, precision_score, recall_score, f1_score
from sklearn.model_selection import StratifiedKFold, GroupKFold, cross_validate
import numpy as np

# %%
graph_metrics_df = pd.read_csv("../../data/current_graph_metrics.csv")
statuses_df = pd.read_csv("../../data/surface_and_status.csv")

# %%
df = graph_metrics_df.merge(statuses_df, on="SpecID").sort_values(by="SpecID").set_index('SpecID')
df
# Out:
#              PageRank  DegreeCentrality  EigenvectorCentrality  ArticleRank  \
# SpecID
# 201210-1-00  0.830275       1170.371464               0.014458     0.195683
# 201210-1-01  0.811969       1134.613827               0.014017     0.194311
# 201210-1-02  0.580317        733.700940               0.009064     0.178658
# 201210-1-03  0.744123       1017.430766               0.012569     0.189725
# 201210-1-04  0.794119       1107.509457               0.013682     0.193235
# ...               ...               ...                    ...          ...
# 210526-3-45  1.128517       1689.660278               0.020874     0.215918
# 210526-3-46  1.110504       1658.692469               0.020491     0.214711
# 210526-3-47  1.145219       1718.172663               0.021226     0.217025
# 210526-3-48  1.084825       1613.192575               0.019929     0.212946
# 210526-3-49  1.121310       1675.383318               0.020697     0.215370
#
#              LabelPropagation  Leiden  Louvain     SurID         Status
# SpecID
# 201210-1-00                 1       1     2289  201210-1         Normal
# 201210-1-01                 1       1     2289  201210-1         Normal
# 201210-1-02                 1     127      988  201210-1         Normal
# 201210-1-03                 1       1     2289  201210-1         Normal
# 201210-1-04                 1       1     2289  201210-1         Normal
# ...                       ...     ...      ...       ...            ...
# 210526-3-45                 1       1     2289  210526-3  Hyperglycemia
# 210526-3-46                 1       1     2289  210526-3  Hyperglycemia
# 210526-3-47                 1       1     2289  210526-3  Hyperglycemia
# 210526-3-48                 1       1     2289  210526-3  Hyperglycemia
# 210526-3-49                 1       1     2289  210526-3  Hyperglycemia
#
# [3045 rows x 9 columns]

# %%
def evaluate_svm(df):
    # Set the Surfaces as groups
    groups = df['SurID']
    X = df.drop(['Status', 'SurID'], axis=1)
    y = df['Status']

    # Creating the SVM classifier
    #svm = SVC(random_state=1234)
    svm = SVC(random_state=1234, kernel='linear')
    
    # Using GroupKFold for classification tasks
    cv = GroupKFold(n_splits=5)

    scores = cross_validate(svm, X, y, groups=groups, cv=cv, scoring=['accuracy'], n_jobs=-1)
    
    # Displaying the results
    print(f'{svm.__class__.__name__} Cross-Validation Accuracy: {np.mean(scores["test_accuracy"]):.4f} +/- {np.std(scores["test_accuracy"]):.4f}')

# %%
evaluate_svm(df)

# %% [markdown]
# >#### Classify based on FastRP Embeddings

# %%
fastRP_df = pd.read_csv("../../data/fastRP_embeddings.csv")

# %%
df = fastRP_df.merge(statuses_df, on="SpecID").sort_values(by="SpecID").set_index('SpecID')
df
# Out:
#              embedding_0  embedding_1  embedding_2  embedding_3  embedding_4  \
# SpecID
# 201210-1-00    -0.080063     0.134346     0.311409     0.068268     0.220651
# 201210-1-01    -0.080101     0.134585     0.310871     0.067332     0.220452
# 201210-1-02    -0.079054     0.138156     0.306293     0.055854     0.212508
# 201210-1-03    -0.079920     0.136971     0.307921     0.059693     0.213916
# 201210-1-04    -0.079154     0.133878     0.312250     0.070663     0.223848
# ...                  ...          ...          ...          ...          ...
# 210526-3-45    -0.077160     0.133637     0.313199     0.071438     0.226589
# 210526-3-46    -0.077198     0.133361     0.313462     0.072150     0.227169
# 210526-3-47    -0.076899     0.134395     0.312508     0.069708     0.225286
# 210526-3-48    -0.077383     0.132969     0.313717     0.072891     0.227793
# 210526-3-49    -0.077301     0.133798     0.312925     0.070852     0.226016
#
#              embedding_5  embedding_6  embedding_7  embedding_8  embedding_9  \
# SpecID
# 201210-1-00     0.020809    -0.157989    -0.023693     0.139395     0.119681
# 201210-1-01     0.020230    -0.158860    -0.023553     0.139669     0.118961
# 201210-1-02     0.017010    -0.174445    -0.019908     0.143086     0.116697
# 201210-1-03     0.018670    -0.169574    -0.020787     0.141887     0.117424
# 201210-1-04     0.020361    -0.154181    -0.024949     0.138894     0.120166
# ...                  ...          ...          ...          ...          ...
# 210526-3-45     0.019494    -0.154102    -0.025647     0.139182     0.121855
# 210526-3-46     0.019669    -0.153159    -0.025882     0.138980     0.122001
# 210526-3-47     0.019181    -0.156088    -0.025093     0.139682     0.121436
# 210526-3-48     0.019769    -0.152275    -0.026112     0.138768     0.122063
# 210526-3-49     0.019378    -0.154794    -0.025419     0.139354     0.121517
#
#              ...  embedding_119  embedding_120  embedding_121  embedding_122  \
# SpecID       ...
# 201210-1-00  ...       0.062691      -0.112076       0.184696       0.327179
# 201210-1-01  ...       0.063693      -0.111742       0.186010       0.326752
# 201210-1-02  ...       0.065156      -0.112998       0.196053       0.328230
# 201210-1-03  ...       0.063974      -0.112868       0.192851       0.328275
# 201210-1-04  ...       0.062828      -0.111242       0.182163       0.326090
# ...          ...            ...            ...            ...            ...
# 210526-3-45  ...       0.062112      -0.111478       0.180060       0.326621
# 210526-3-46  ...       0.062088      -0.111391       0.179395       0.326495
# 210526-3-47  ...       0.062091      -0.111497       0.181595       0.326650
# 210526-3-48  ...       0.062284      -0.111309       0.178866       0.326396
# 210526-3-49  ...       0.062324      -0.111432       0.180828       0.326613
#
#              embedding_123  embedding_124  embedding_125  embedding_126  \
# SpecID
# 201210-1-00      -0.075120       0.091235      -0.209512       0.040763
# 201210-1-01      -0.076596       0.091260      -0.211565       0.040145
# 201210-1-02      -0.083976       0.093691      -0.220491       0.040576
# 201210-1-03      -0.082046       0.093300      -0.217178       0.040930
# 201210-1-04      -0.072420       0.090532      -0.207949       0.039952
# ...                    ...            ...            ...            ...
# 210526-3-45      -0.067590       0.089882      -0.204368       0.040522
# 210526-3-46      -0.067051       0.089678      -0.203765       0.040492
# 210526-3-47      -0.068859       0.090412      -0.205910       0.040582
# 210526-3-48      -0.066739       0.089389      -0.203345       0.040377
# 210526-3-49      -0.068505       0.090033      -0.205280       0.040432
#
#              embedding_127         Status
# SpecID
# 201210-1-00      -0.094208         Normal
# 201210-1-01      -0.094633         Normal
# 201210-1-02      -0.086324         Normal
# 201210-1-03      -0.088214         Normal
# 201210-1-04      -0.096966         Normal
# ...                    ...            ...
# 210526-3-45      -0.096711  Hyperglycemia
# 210526-3-46      -0.097252  Hyperglycemia
# 210526-3-47      -0.095570  Hyperglycemia
# 210526-3-48      -0.097908  Hyperglycemia
# 210526-3-49      -0.096475  Hyperglycemia
#
# [3045 rows x 129 columns]

# %%
evaluate_svm(df)
# Out:
# Overall Accuracy: 0.7934426229508197
#
#
# Classification Report:
#                precision    recall  f1-score   support
#
# Hyperglycemia       0.72      0.74      0.73        91
#  Hypoglycemia       0.81      0.78      0.79       107
#        Normal       0.84      0.86      0.85       107
#
#      accuracy                           0.79       305
#     macro avg       0.79      0.79      0.79       305
#  weighted avg       0.79      0.79      0.79       305
#
#
# Confusion Matrix:
# [[67 15  9]
#  [15 83  9]
#  [11  4 92]]
# Overall Accuracy: 0.7672131147540984
#
#
# Classification Report:
#                precision    recall  f1-score   support
#
# Hyperglycemia       0.73      0.79      0.76        91
#  Hypoglycemia       0.76      0.69      0.73       107
#        Normal       0.81      0.82      0.81       107
#
#      accuracy                           0.77       305
#     macro avg       0.77      0.77      0.77       305
#  weighted avg       0.77      0.77      0.77       305
#
#
# Confusion Matrix:
# [[72 12  7]
#  [19 74 14]
#  [ 8 11 88]]
# Overall Accuracy: 0.7573770491803279
#
#
# Classification Report:
#                precision    recall  f1-score   support
#
# Hyperglycemia       0.70      0.74      0.72        91
#  Hypoglycemia       0.80      0.78      0.79       107
#        Normal       0.77      0.76      0.76       107
#
#      accuracy                           0.76       305
#     macro avg       0.76      0.76      0.76       305
#  weighted avg       0.76      0.76      0.76       305
#
#
# Confusion Matrix:
# [[67 11 13]
#  [13 83 11]
#  [16 10 81]]
# Overall Accuracy: 0.7704918032786885
#
#
# Classification Report:
#                precision    recall  f1-score   support
#
# Hyperglycemia       0.70      0.74      0.72        91
#  Hypoglycemia       0.74      0.81      0.77       107
#        Normal       0.89      0.76      0.82       107
#
#      accuracy                           0.77       305
#     macro avg       0.78      0.77      0.77       305
#  weighted avg       0.78      0.77      0.77       305
#
#
# Confusion Matrix:
# [[67 18  6]
#  [16 87  4]
#  [13 13 81]]
# Overall Accuracy: 0.7540983606557377
#
#
# Classification Report:
#                precision    recall  f1-score   support
#
# Hyperglycemia       0.69      0.63      0.66        91
#  Hypoglycemia       0.76      0.78      0.77       107
#        Normal       0.80      0.84      0.82       107
#
#      accuracy                           0.75       305
#     macro avg       0.75      0.75      0.75       305
#  weighted avg       0.75      0.75      0.75       305
#
#
# Confusion Matrix:
# [[57 19 15]
#  [16 83  8]
#  [10  7 90]]
# Overall Accuracy: 0.7302631578947368
#
#
# Classification Report:
#                precision    recall  f1-score   support
#
# Hyperglycemia       0.67      0.71      0.69        92
#  Hypoglycemia       0.71      0.74      0.72       106
#        Normal       0.81      0.75      0.78       106
#
#      accuracy                           0.73       304
#     macro avg       0.73      0.73      0.73       304
#  weighted avg       0.73      0.73      0.73       304
#
#
# Confusion Matrix:
# [[65 16 11]
#  [21 78  7]
#  [11 16 79]]
# Overall Accuracy: 0.805921052631579
#
#
# Classification Report:
#                precision    recall  f1-score   support
#
# Hyperglycemia       0.79      0.75      0.77        92
#  Hypoglycemia       0.78      0.75      0.77       106
#        Normal       0.83      0.91      0.87       106
#
#      accuracy                           0.81       304
#     macro avg       0.80      0.80      0.80       304
#  weighted avg       0.80      0.81      0.80       304
#
#
# Confusion Matrix:
# [[69 16  7]
#  [14 80 12]
#  [ 4  6 96]]
# Overall Accuracy: 0.7796052631578947
#
#
# Classification Report:
#                precision    recall  f1-score   support
#
# Hyperglycemia       0.76      0.77      0.77        92
#  Hypoglycemia       0.79      0.73      0.75       106
#        Normal       0.79      0.84      0.81       106
#
#      accuracy                           0.78       304
#     macro avg       0.78      0.78      0.78       304
#  weighted avg       0.78      0.78      0.78       304
#
#
# Confusion Matrix:
# [[71 12  9]
#  [14 77 15]
#  [ 8  9 89]]
# Overall Accuracy: 0.7664473684210527
#
#
# Classification Report:
#                precision    recall  f1-score   support
#
# Hyperglycemia       0.74      0.71      0.72        92
#  Hypoglycemia       0.78      0.77      0.78       106
#        Normal       0.77      0.81      0.79       106
#
#      accuracy                           0.77       304
#     macro avg       0.76      0.76      0.76       304
#  weighted avg       0.77      0.77      0.77       304
#
#
# Confusion Matrix:
# [[65 13 14]
#  [13 82 11]
#  [10 10 86]]
# Overall Accuracy: 0.7532894736842105
#
#
# Classification Report:
#                precision    recall  f1-score   support
#
# Hyperglycemia       0.70      0.66      0.68        92
#  Hypoglycemia       0.72      0.75      0.74       106
#        Normal       0.83      0.83      0.83       106
#
#      accuracy                           0.75       304
#     macro avg       0.75      0.75      0.75       304
#  weighted avg       0.75      0.75      0.75       304
#
#
# Confusion Matrix:
# [[61 21 10]
#  [18 80  8]
#  [ 8 10 88]]
# Accuracy: 0.7678 +/- 0.0204
# Precision: 0.7688 +/- 0.0200
# Recall: 0.7678 +/- 0.0204
# F1-Score: 0.7676 +/- 0.0201
