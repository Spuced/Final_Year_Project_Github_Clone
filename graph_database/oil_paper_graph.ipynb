# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../../data/pivoted_scaled_and_noise_removal.csv", index_col=0)

# %%
df.head()
# Out:
#                 200.0  200.68336  201.36674  202.05011  202.73349  203.41685  \
# SpecID
# 201210-1-00  1.000000   0.982870   0.966481   0.950833   0.935925   0.927346
# 201210-1-01  1.000000   0.980550   0.964007   0.950373   0.939647   0.930871
# 201210-1-02  0.502527   0.491051   0.479540   0.467993   0.456410   0.450161
# 201210-1-03  0.492251   0.418315   0.375666   0.364304   0.384230   0.461173
# 201210-1-04  1.000000   0.994372   0.989487   0.985346   0.981948   0.976845
#
#              204.10023  204.7836  205.46696  206.15034  ...  1994.5331  \
# SpecID                                                  ...
# 201210-1-00   0.902431  0.889797   0.880243   0.864841  ...   0.070690
# 201210-1-01   0.928574  0.925606   0.914910   0.900030  ...   0.113337
# 201210-1-02   0.431959  0.424441   0.417415   0.408823  ...   0.144569
# 201210-1-03   0.570848  0.577491   0.675831   0.807648  ...   0.005644
# 201210-1-04   0.970762  0.977536   0.981513   0.963198  ...   0.019359
#
#              1995.2164  1995.8998  1996.5831  1997.2665  1997.9498  1998.6333  \
# SpecID
# 201210-1-00   0.082414   0.090970   0.092890   0.083230   0.082239   0.082605
# 201210-1-01   0.117351   0.131463   0.146428   0.158236   0.161601   0.160516
# 201210-1-02   0.141991   0.139207   0.144627   0.149526   0.150847   0.150600
# 201210-1-03   0.007747   0.008992   0.010157   0.011991   0.011822   0.010642
# 201210-1-04   0.028442   0.041845   0.058730   0.063852   0.070008   0.074530
#
#              1999.3167    2000.0  Status
# SpecID
# 201210-1-00   0.084328  0.087409  Normal
# 201210-1-01   0.154980  0.144994  Normal
# 201210-1-02   0.148786  0.145404  Normal
# 201210-1-03   0.008451  0.005248  Normal
# 201210-1-04   0.077417  0.078669  Normal
#
# [5 rows x 2636 columns]

# %% [markdown]
# Use the Gausian Kernal Function to Map the Euclidian Distance between all the samples between 0 and 1.

# %% [markdown]
# Calculate the euclidean distance between each pair of samples.

# %%
import pandas as pd
from scipy.spatial.distance import pdist, squareform

# Drop the 'Status' column as it is not numeric
X = df.drop(columns=['Status'])

# Calculate pairwise Euclidean distances
distances = pdist(X.values, metric='euclidean')

# Convert the condensed distances to a square matrix form
distance_matrix = squareform(distances)

# %% [markdown]
# Complete the Gaussian Kernel.
#
# Different Sigmas should be tested.

# %%
import numpy as np

def gaussian_kernel(distances, sigma):
    return np.exp(-distances**2 / (2 * sigma**2))

# Sigma is the bandwidth parameter
sigma = 5 # Adjust sigma as needed
kernel_matrix = gaussian_kernel(distance_matrix, sigma)

# Convert the kernel matrix to a DataFrame
kernel_df = pd.DataFrame(kernel_matrix, index=df.index, columns=df.index)

# %%
kernel_df
# Out:
# SpecID       201210-1-00  201210-1-01  201210-1-02  201210-1-03  201210-1-04  \
# SpecID
# 201210-1-00     1.000000     0.894630     0.352346     0.580781     0.729355
# 201210-1-01     0.894630     1.000000     0.407430     0.574409     0.726130
# 201210-1-02     0.352346     0.407430     1.000000     0.583782     0.212543
# 201210-1-01     0.541225
# 201210-1-02     0.242785
# 201210-1-03     0.394539
# 201210-1-04     0.563820
# ...                  ...
# 210526-3-45     0.885957
# 210526-3-46     0.890028
# 210526-3-47     0.886248
# 210526-3-48     0.881786
# 210526-3-49     1.000000
#
# [3045 rows x 3045 columns]

# %% [markdown]
# Create the graph structure.

# %% [markdown]
# Create the node information.

# %%
df.index
# Out:
# Index(['201210-1-00', '201210-1-01', '201210-1-02', '201210-1-03',
#        '201210-1-04', '201210-1-05', '201210-1-06', '201210-1-07',
#        '201210-1-09', '201210-1-10',
#        ...
#        '210526-3-40', '210526-3-41', '210526-3-42', '210526-3-43',
#        '210526-3-44', '210526-3-45', '210526-3-46', '210526-3-47',
#        '210526-3-48', '210526-3-49'],
#       dtype='object', name='SpecID', length=3045)

# %%
nodes_df = df['Status'].to_frame()
nodes_df.head()
# Out:
#              Status
# SpecID
# 201210-1-00  Normal
# 201210-1-01  Normal
# 201210-1-02  Normal
# 201210-1-03  Normal
# 201210-1-04  Normal

# %% [markdown]
# Use the Neo4j Naming Scheme.

# %% [markdown]
# Create the nodes CSV.

# %%
nodes_df = nodes_df.rename_axis("SpecID:ID")
nodes_df = nodes_df.rename(columns={"Status": ":LABEL"})

# %%
nodes_df
# Out:
#                     :LABEL
# SpecID:ID
# 201210-1-00         Normal
# 201210-1-01         Normal
# 201210-1-02         Normal
# 201210-1-03         Normal
# 201210-1-04         Normal
# ...                    ...
# 210526-3-45  Hyperglycemia
# 210526-3-46  Hyperglycemia
# 210526-3-47  Hyperglycemia
# 210526-3-48  Hyperglycemia
# 210526-3-49  Hyperglycemia
#
# [3045 rows x 1 columns]

# %%
#nodes_df.to_csv("../../data/gaussian_kernel/nodes.csv")
nodes_df.to_csv("../../data/current_working_graph/nodes.csv")

# %% [markdown]
# Create the relationships CSV.

# %%
kernel_df.head()
# Out:
# SpecID       201210-1-00  201210-1-01  201210-1-02  201210-1-03  201210-1-04  \
# SpecID
# 201210-1-00     1.000000     0.894630     0.352346     0.580781     0.729355
# 201210-1-01     0.894630     1.000000     0.407430     0.574409     0.726130
# 201210-1-02     0.352346     0.407430     1.000000     0.583782     0.212543
# 201210-1-03     0.580781     0.574409     0.583782     1.000000     0.376487
# 201210-1-04     0.729355     0.726130     0.212543     0.376487     1.000000
#
# SpecID       201210-1-05  201210-1-06  201210-1-07  201210-1-09  201210-1-10  \
# SpecID
# 201210-1-00     0.735979     0.709280     0.677789     0.659652     0.699597
# 201210-1-01     0.734387     0.750640     0.695554     0.691304     0.703195
# 201210-1-02     0.246364     0.301411     0.391488     0.394266     0.362152
# 201210-1-03     0.412051     0.543609     0.698144     0.653341     0.591198
# 201210-1-04     0.866288     0.644149     0.515426     0.491367     0.561159
#
# SpecID       ...  210526-3-40  210526-3-41  210526-3-42  210526-3-43  \
# SpecID       ...
# 201210-1-00  ...     0.548901     0.520620     0.491469     0.531072
# 201210-1-01  ...     0.510744     0.488992     0.466147     0.492284
# 201210-1-02  ...     0.209162     0.187038     0.191487     0.192305
# 201210-1-03  ...     0.356342     0.322006     0.315554     0.334166
# 201210-1-04  ...     0.560071     0.547044     0.510333     0.549495
#
# SpecID       210526-3-44  210526-3-45  210526-3-46  210526-3-47  210526-3-48  \
# SpecID
# 201210-1-00     0.530533     0.563141     0.552675     0.580035     0.548277
# 201210-1-01     0.488119     0.530495     0.515895     0.545703     0.512607
# 201210-1-02     0.190531     0.227350     0.211646     0.275215     0.202931
# 201210-1-03     0.331941     0.382020     0.353671     0.417015     0.348770
# 201210-1-04     0.547174     0.561795     0.565484     0.555025     0.556761
#
# SpecID       210526-3-49
# SpecID
# 201210-1-00     0.580868
# 201210-1-01     0.541225
# 201210-1-02     0.242785
# 201210-1-03     0.394539
# 201210-1-04     0.563820
#
# [5 rows x 3045 columns]

# %%
relationship_df = kernel_df.reset_index()
relationship_df = relationship_df.melt(id_vars='SpecID', var_name=':END_ID', value_name='Weight:float')
relationship_df = relationship_df.rename(columns={'SpecID': ':START_ID'})
relationship_df[':TYPE'] = 'LINK'

# %%
relationship_df
# Out:
#            :START_ID      :END_ID  Weight:float :TYPE
# 0        201210-1-00  201210-1-00      1.000000  LINK
# 1        201210-1-01  201210-1-00      0.894630  LINK
# 2        201210-1-02  201210-1-00      0.352346  LINK
# 3        201210-1-03  201210-1-00      0.580781  LINK
# 4        201210-1-04  201210-1-00      0.729355  LINK
# ...              ...          ...           ...   ...
# 9272020  210526-3-45  210526-3-49      0.885957  LINK
# 9272021  210526-3-46  210526-3-49      0.890028  LINK
# 9272022  210526-3-47  210526-3-49      0.886248  LINK
# 9272023  210526-3-48  210526-3-49      0.881786  LINK
# 9272024  210526-3-49  210526-3-49      1.000000  LINK
#
# [9272025 rows x 4 columns]

# %% [markdown]
# Drop all the relationships a node has with itself, as well as the repeated two way relationship.

# %%
relationship_df = relationship_df[relationship_df[":START_ID"] != relationship_df[":END_ID"]]
relationship_df = relationship_df[relationship_df[":START_ID"] < relationship_df[":END_ID"]]

# %%
relationship_df
# Out:
#            :START_ID      :END_ID  Weight:float :TYPE
# 3045     201210-1-00  201210-1-01      0.894630  LINK
# 6090     201210-1-00  201210-1-02      0.352346  LINK
# 6091     201210-1-01  201210-1-02      0.407430  LINK
# 9135     201210-1-00  201210-1-03      0.580781  LINK
# 9136     201210-1-01  201210-1-03      0.574409  LINK
# ...              ...          ...           ...   ...
# 9272019  210526-3-44  210526-3-49      0.880246  LINK
# 9272020  210526-3-45  210526-3-49      0.885957  LINK
# 9272021  210526-3-46  210526-3-49      0.890028  LINK
# 9272022  210526-3-47  210526-3-49      0.886248  LINK
# 9272023  210526-3-48  210526-3-49      0.881786  LINK
#
# [4634490 rows x 4 columns]

# %%
#relationship_df.to_csv("../../data/gaussian_kernel/relationships.csv",index=False)

# %%
nodes_df.to_csv("../../data/gaussian_kernel/nodes.csv")
relationship_df.to_csv("../../data/current_working_graph/relationships.csv")
