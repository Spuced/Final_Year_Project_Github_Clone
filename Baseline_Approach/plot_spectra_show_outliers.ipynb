# %% [markdown]
# Import the libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sys
sys.path.append('..')
from Cleaning_and_Evaluation import *

# %% [markdown]
# Read the spectral data into Pandas

# %%
spectra_df = pd.read_csv("../data/exosomes.raw_spectrum_1.csv")

# %%
spectra_df.head()
# Out:
#         SpecID  Seq  WaveNumber     SurID  Status  Absorbance
# 0  201210-1-00  293   400.22778  201210-1  Normal   -0.019205
# 1  201210-1-00  294   400.91116  201210-1  Normal   -0.111056
# 2  201210-1-00  295   401.59454  201210-1  Normal   -0.182767
# 3  201210-1-00  296   402.27789  201210-1  Normal   -0.236198
# 4  201210-1-00  297   402.96127  201210-1  Normal   -0.273213

# %%
spec_id = pd.unique(spectra_df['SpecID'])

# %%
sns.set_style("whitegrid")

# %%
spec_id
# Out:
# array(['201210-1-00', '201210-1-01', '201210-1-02', ..., '210526-3-07',
#        '210526-3-08', '210526-3-09'], dtype=object)

# %%
sample_normal = spectra_df[spectra_df['SurID'] == "201210-1"]

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data=sample_normal, x='WaveNumber', y='Absorbance', hue="SpecID", legend=False)
plt.title("Plot of Every Spectra in One Surface (201210-1)")
plt.ylim(-4, 9)
plt.show()

# %%
sample_normal = spectra_df[spectra_df['SurID'] == "210526-3"]

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data=sample_normal, x='WaveNumber', y='Absorbance', hue="SpecID", legend=False)
plt.title("Plot of Every Spectra in One Surface (210526-3)")
plt.ylim(-3, 8)
plt.show()

# %%
sample_outlier = spectra_df[spectra_df['SpecID'] == "201210-1"]

# %%
sns.lineplot(data=sample_outlier, x='WaveNumber', y='Absorbance')
# Out:
# <Axes: xlabel='WaveNumber', ylabel='Absorbance'>
